# %%
import pandas as pd
import datetime as dt

feather = pd.read_feather('incendie_final.feather')
feather = feather.sort_values('date').reset_index()
feather['days_since_rain'].plot()
# Out:
# <Axes: >

# %%
feather['sum_rain_last_7_days'].plot()
# Out:
# <Axes: >

# %%
feather['feux'].sum()
# Out:
# 1.0

# %%
feather.date.values[-1]
# Out:
# datetime.date(2024, 7, 30)

# %%
import geopandas as gpd

feux = feather[feather['date'] == dt.datetime.strptime('2024-07-30', '%Y-%m-%d').date()]

feux = gpd.GeoDataFrame(feux, geometry=feux.geometry)
feux.plot(columns='feux')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 6
#       2 import geopandas as gpd
#       4 feux = feather[feather['date'] == dt.datetime.strptime('2024-07-30', '%Y-%m-%d').date()]
# ----> 6 feux = gpd.GeoDataFrame(feux, geometry=feux.geometry)
#       7 feux.plot(columns='feux')
#
# File ~/Bureau/.conda/lib/python3.9/site-packages/geopandas/geodataframe.py:192, in GeoDataFrame.__init__(self, data, geometry, crs, *args, **kwargs)
#     184     if (
#     185         hasattr(geometry, "crs")
#     186         and geometry.crs
#     187         and crs
#     188         and not geometry.crs == crs
#     189     ):
#     190         raise ValueError(crs_mismatch_error)
# --> 192     self.set_geometry(geometry, inplace=True, crs=crs)
#     194 if geometry is None and crs:
#     195     raise ValueError(
# ...
