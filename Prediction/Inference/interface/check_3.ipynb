# %%
import pandas as pd
import datetime as dt

feather = pd.read_feather('incendie_final_doubs.feather')
feather = feather.sort_values('date').reset_index()
feather['days_since_rain'].plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import datetime as dt
# ----> 4 feather = pd.read_feather('incendie_final_doubs.feather')
#       5 feather = feather.sort_values('date').reset_index()
#       6 feather['days_since_rain'].plot()
#
# File ~/Bureau/.conda/lib/python3.9/site-packages/pandas/io/feather_format.py:120, in read_feather(path, columns, use_threads, storage_options, dtype_backend)
#     116 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     118 check_dtype_backend(dtype_backend)
# --> 120 with get_handle(
#     121     path, "rb", storage_options=storage_options, is_text=False
#     122 ) as handles:
#     123     if dtype_backend is lib.no_default and not using_pyarrow_string_dtype():
#     124         return feather.read_feather(
# ...

# %%
import pickle
import weigh_predictor

od = pickle.load(open('departement-25-doubsPredictor60.pkl', 'rb'))
od.cluster_centers.round()
# Out:
# array([[ 0.],
#        [15.],
#        [ 8.],
#        [29.],
#        [ 3.]])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Création des données
x = np.linspace(0, 10, 100)
y1 = np.sin(x)  # Première courbe
y2 = np.exp(x / 10)  # Deuxième courbe avec une autre échelle

# Création de la figure et de l'axe principal
fig, ax1 = plt.subplots()

# Tracé de la première courbe
ax1.plot(x, y1, 'b-', label='sin(x)')
ax1.set_xlabel('X')
ax1.set_ylabel('sin(x)', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Création du second axe partageant le même axe x
ax2 = ax1.twinx()

# Tracé de la deuxième courbe
ax2.plot(x, y2, 'r-', label='exp(x/10)')
ax2.set_ylabel('exp(x/10)', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# Ajout des légendes
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Affichage du plot
plt.show()

# %%
df = pd.read_csv('2024-08-06.csv')
df['temp_mean']
# Out:
# 0     25.759
# 1     27.101
# 2     24.456
# 3     22.817
# 4     24.742
# 5     21.081
# 6     21.881
# 7     23.634
# 8     20.607
# 9     24.699
# 10    26.145
# 11    23.267
# 12    26.342
# 13    27.320
# 14    25.344
# 15    28.431
# 16    30.645
# 17    27.469
# 18    29.420
# 19    31.238
# 20    26.934
# 21    29.900
# 22    29.809
# 23    27.220
# Name: temp_mean, dtype: float64

# %%
df2 = pd.read_csv('../log/2024-08-06.csv')
df2['sum_rain_last_7_days_max'].plot()
df['sum_rain_last_7_days_max'].plot()
# Out:
# <Axes: >

# %%
df2.SUM
# Out:
# Index(['id', 'longitude', 'latitude', 'departement', 'date', 'weight',
#        'temp_mean', 'temp_min', 'temp_max', 'temp_std',
#        ...
#        'confinemenent_sum_7', 'ramadan_sum_7', 'bankHolidays_sum_7',
#        'bankHolidaysEve_sum_7', 'holidays_sum_7', 'holidaysBorder_sum_7',
#        'calendar_mean_sum_7', 'calendar_min_sum_7', 'calendar_max_sum_7',
#        'calendar_sum_sum_7'],
#       dtype='object', length=1818)

# %%
feather['sum_rain_last_7_days'].plot()
# Out:
# <Axes: >

# %%
feather['feux'].sum()
# Out:
# 17.0

# %%
feather.date.values[-1]
# Out:
# datetime.date(2024, 8, 13)

# %%
import geopandas as gpd

feux = feather[feather['date'] == dt.datetime.strptime('2024-08-12', '%Y-%m-%d').date()]
feux.prcp.max(), feux.prcp.min(), feux.prcp.mean()
# Out:
# (0.3482492820017034, 0.0, 0.006354007096061241)
