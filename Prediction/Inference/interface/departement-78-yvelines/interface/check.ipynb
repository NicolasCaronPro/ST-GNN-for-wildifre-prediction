# %%
import geopandas as gpd

geo = gpd.read_file('hexagones_2024-07-31.geojson')
geo.plot(column='fire_prediction', vmin=0, vmax=4, cmap='jet', categorical=True, legend=True)
geo.plot(column='fire_prediction_raw', cmap='jet', vmin=0, vmax=50)
geo.plot(column='fire_prediction_dept', cmap='jet', vmin=0, vmax=4)
# Out:
# <Axes: >

# %%
geo.fire_prediction_dept
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1153    0
# 1154    0
# 1155    0
# 1156    0
# 1157    0
# Name: fire_prediction_dept, Length: 1158, dtype: int64

# %%
geo.fire_prediction_raw
# Out:
# 0       0.678696
# 1       0.977198
# 2       2.880451
# 3       8.373602
# 4       2.880451
#           ...
# 1153    3.113708
# 1154    3.113708
# 1155    0.180460
# 1156    5.251699
# 1157    0.252728
# Name: fire_prediction_raw, Length: 1158, dtype: float64

# %%
import geopandas as gpd

geo = gpd.read_file('hexagones_tomorrow.geojson')
geo.plot(column='fire_prediction', vmin=0, vmax=4, cmap='jet', categorical=True, legend=True)
geo.plot(column='fire_prediction_raw', cmap='jet')
geo.plot(column='fire_prediction_dept', cmap='jet')
# Out:
# <Axes: >

# %%
geo.fire_prediction
# Out:
# 0       0.0
# 1       0.0
# 2       0.0
# 3       3.0
# 4       0.0
#        ...
# 1153    1.0
# 1154    1.0
# 1155    0.0
# 1156    0.0
# 1157    0.0
# Name: fire_prediction, Length: 1158, dtype: float64

# %%
geo.columns
# Out:
# Index(['hex_id', 'index_right', 'code_insee', 'nom', 'nuts3', 'wikipedia',
#        'surf_km2', 'temperature', 'dwpt', 'humidite', 'precipitations',
#        'neige', 'direction_vent', 'vitesse_vent', 'pres', 'prec24h',
#        'prec24h12', 'temp16', 'dwpt16', 'rhum16', 'prcp16', 'wdir16', 'wspd16',
#        'prec24h16', 'temp15h', 'rhum15h', 'temp12h', 'rhum12h', 'temp24max',
#        'prec24veille', 'sum_last_7_days', 'sum_consecutive_rainfall', 'dc',
#        'ffmc', 'dmc', 'isi', 'bui', 'fwi', 'daily_severity_rating', 'nesterov',
#        'munger', 'kbdi', 'angstroem', 'date', 'departement_encoding',
#        'fire_prediction', 'fire_prediction_raw', 'fire_prediction_dept',
#        'geometry'],
#       dtype='object')

# %%
geo.plot(column='departement_encoding')
# Out:
# <Axes: >

# %%
geo
# Out:
#                hex_id  index_right code_insee    nom  nuts3  \
# 0     871f82a71ffffff           97         25  Doubs  FR431
# 1     871f82195ffffff           97         25  Doubs  FR431
# 2     871f82726ffffff           97         25  Doubs  FR431
# 3     871f82813ffffff           97         25  Doubs  FR431
# 4     871f82720ffffff           97         25  Doubs  FR431
# ...               ...          ...        ...    ...    ...
# 1153  871f82b23ffffff           97         25  Doubs  FR431
# 1154  871f82b75ffffff           97         25  Doubs  FR431
# 1155  871f82a1affffff           97         25  Doubs  FR431
# 1156  871f82b71ffffff           97         25  Doubs  FR431
# 1157  871f82336ffffff           97         25  Doubs  FR431
#
#                    wikipedia  surf_km2  temperature       dwpt   humidite  \
# 0     fr:Doubs (département)    5256.0     9.766594   7.838892  87.785044
# 1     fr:Doubs (département)    5256.0     9.429967   7.899789  90.067712
# ...

# %%
import pandas as pd
file = pd.read_feather('incendie_final.feather')
file
# Out:
#                 hex_id                                           geometry  \
# 0      871f82a71ffffff  b"\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# 1      871f82195ffffff  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# 2      871f82726ffffff  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# 3      871f82813ffffff  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# 4      871f82720ffffff  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# ...                ...                                                ...
# 94951  871f82b23ffffff  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# 94952  871f82b75ffffff  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# 94953  871f82a1affffff  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# 94954  871f82b71ffffff  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# 94955  871f82336ffffff  b"\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
#
#             temp       dwpt       rhum      prcp  snow        wdir      wspd  \
# ...

# %%
file.columns
# Out:
# Index(['hex_id', 'geometry', 'temp', 'dwpt', 'rhum', 'prcp', 'snow', 'wdir',
#        'wspd', 'pres', 'prec24h', 'prec24h12', 'temp16', 'dwpt16', 'rhum16',
#        'prcp16', 'wdir16', 'wspd16', 'prec24h16', 'temp12', 'dwpt12', 'rhum12',
#        'prcp12', 'wdir12', 'wspd12', 'temp15h', 'rhum15h', 'temp12h',
#        'rhum12h', 'temp24max', 'prec24veille', 'sum_last_7_days',
#        'sum_consecutive_rainfall', 'dc', 'days_since_rain', 'ffmc', 'dmc',
#        'isi', 'bui', 'fwi', 'daily_severity_rating', 'nesterov', 'munger',
#        'kbdi', 'angstroem', 'date', 'feux', 'feux-1', 'feux-2', 'feux-3',
#        'feux-4', 'feux-5', 'feux-6', 'feux-7'],
#       dtype='object')

# %%
geo.columns
# Out:
# Index(['hex_id', 'index_right', 'code_insee', 'nom', 'nuts3', 'wikipedia',
#        'surf_km2', 'temperature', 'dwpt', 'humidite', 'precipitations',
#        'neige', 'direction_vent', 'vitesse_vent', 'pres', 'prec24h',
#        'prec24h12', 'temp16', 'dwpt16', 'rhum16', 'prcp16', 'wdir16', 'wspd16',
#        'prec24h16', 'temp15h', 'rhum15h', 'temp12h', 'rhum12h', 'temp24max',
#        'prec24veille', 'sum_last_7_days', 'sum_consecutive_rainfall', 'dc',
#        'ffmc', 'dmc', 'isi', 'bui', 'fwi', 'daily_severity_rating', 'nesterov',
#        'munger', 'kbdi', 'angstroem', 'date', 'departement_encoding',
#        'fire_prediction', 'fire_prediction_raw', 'fire_prediction_dept',
#        'geometry'],
#       dtype='object')
