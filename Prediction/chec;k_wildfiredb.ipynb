# %%
import pandas as pd
from pathlib import Path

path = Path('/media/caron/X9 Pro/travaille/Thèse/csv/wildfiredb')
df = pd.read_csv(path / 'wildfiredb.csv')

# %%
import torch

# %%
torch.nn.functional.softplus(torch.as_tensor(0.9))
# Out:
# tensor(1.2412)
