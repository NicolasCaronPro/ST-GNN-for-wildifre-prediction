# %%
import sys
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import logging
from patsy import bs
import itertools

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
# Configuration

MODE = 'firemen'

if MODE == '06':
    base_path = Path('firemen/firepoint/2x2/test/occurence_062023/all/full_all_3_0_zonemeteo_node/')
    parent_dir_name = 'full_all_3_0_zonemeteo_node/'
    path_baseline = Path('06/')
elif MODE == 'bdiff':
    pass
elif MODE == 'firemen':
    base_path = Path('firemen/firepoint/2x2/test/occurence_06_01_25_78/all/full_all_3_0_risk-size-zonemeteo-degree-a3-r5-t0.3_node/')
    parent_dir_name = 'full_all_3_0_risk-size-zonemeteo-degree-a3-r5-t0.3_node/'
    path_baseline = Path('firemen/')

scale = 10
horizon = 0

clustering = 'quantile'

models = [
    'GRU_search_full_10_0_all_one_',
]

losses = [
    'regression_pdegpd',
    'classification_flwki-id{departement}',
    'classification_flwk',
    'classification_weightedcrossentropy',
    'classification_wkloss',
    'classification_bceloss',
    'classification_fl',
    'regression_cll',
]

targets = [
   f'nbsinister-{clustering}-5-Class-Dept',
   #f'timeintervention-{clustering}-5-Class-Dept',
   #f'ressource-{clustering}-5-Class-Dept',
]

all_dir = list(itertools.product(models, losses, targets))

loss_2 = ["regression_ccllt-id{node}-nclusters{30}"]
targets_2 = ["nbsinister"]

all_dir_2 = list(itertools.product(models, loss_2, targets_2))

all_dir = all_dir + all_dir_2

# %%
import os
import io
import pandas as pd
import paramiko

def list_remote_pkl_files(sftp, remote_dir):
    pkl_files = []

    # 1) essayer remote_dir/H0/*.pkl
    h0_dir = remote_dir.rstrip("/") + "/H0"
    try:
        for f in sftp.listdir(h0_dir):
            if f.endswith(".pkl"):
                pkl_files.append(h0_dir + "/" + f)
    except FileNotFoundError:
        pass

    # 2) sinon remote_dir/*.pkl
    if not pkl_files:
        try:
            for f in sftp.listdir(remote_dir):
                if f.endswith(".pkl"):
                    pkl_files.append(remote_dir.rstrip("/") + "/" + f)
        except FileNotFoundError:
            pass

    return pkl_files

def read_remote_pickle(sftp, remote_file_path):
    # Lire le fichier distant dans un buffer mémoire puis le donner à pandas
    with sftp.open(remote_file_path, "rb") as f:
        data = f.read()
    return pd.read_pickle(io.BytesIO(data))

def find_remote_directories(sftp, base_path_remote, all_dir):
    matches = []

    # Vérifie que base_path_remote existe
    try:
        sftp.listdir(base_path_remote)
    except FileNotFoundError:
        print(f"Base path does not exist on remote: {base_path_remote}")
        return []

    for (model, loss, target) in all_dir:
        print(model, loss, target)
        dir_name = f"{model}{target}_{loss}"
        full_path = base_path_remote.rstrip("/") + "/" + dir_name
        try:
            # Si listdir marche, c'est un dossier existant
            sftp.listdir(full_path)
            matches.append((full_path, model, loss, target))
        except FileNotFoundError:
            continue

    return matches

TARGET_MAP = {
    "nbsinister-quantile-5-Class-Dept": "nbsinister",
}

_INV_CLLT_TARGET_MAP = {v: k for k, v in TARGET_MAP.items()}

# --- Connexion SSH ---
hostname = "mesohelios1.univ-fcomte.fr"
username = "ncaron"
password = "xp2nrfeu"
#key_path = "/chemin/vers/id_rsa"  # si clé

ssh = paramiko.SSHClient()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
ssh.connect(hostname, username=username, password=password)

sftp = ssh.open_sftp()

# --- Utilisation ---
base_path_remote = (Path("/Home/Users/ncaron/WORK/GNN") / base_path).as_posix()
directories = find_remote_directories(sftp, base_path_remote, all_dir)
print(f"Found {len(directories)} directories matching configuration.")

all_data_frames = {}
gt_dfs = {}
target_cols = {}

for d, model, loss, target in directories:

    if target not in all_data_frames.keys():
        all_data_frames[target] = {}
    if target is None:
        continue

    pkl_files = list_remote_pkl_files(sftp, d)
    if not pkl_files:
        continue

    file_path = pkl_files[0]
    
    try:
        res = read_remote_pickle(sftp, file_path)
    except Exception as e:
        print(f"Error loading {d}: {e}")
        continue

    if target in ["ressource", "timeintervention", "nbsinister"]:
        target = _INV_CLLT_TARGET_MAP[target]

    if "date" not in res.columns or "graph_id" not in res.columns:
        print(f"Skipping {d}: missing date or graph_id")
        continue

    pred_col = f"prediction_{target}_0"
    if pred_col not in res.columns:
        if target in res.columns:
            pred_col = target
        else:
            print(f"Skipping {d}: no prediction column")
            continue

    df = res[["date", "departement", "graph_id", target]].copy()
    df["risk_score"] = res[pred_col]
    df[pred_col] = res[pred_col]
    df["config"] = f"{model}{loss}"

    if "nbsinister" in target:
        df["nbsinister"] = res["nbsinister"]
    elif "ressource" in target:
        df['ressource'] = res['ressource']
    elif 'time' in target:
        df["time_intervention"] = res['time_intervention']
    else:
        df["burnedareaRoot"] = res["burnedareaRoot"]

    df["num_zone"] = df["graph_id"]
    all_data_frames[target][f"{model}{loss}"] = df

    baseline_col = f"{target}"
    has_baseline = baseline_col in res.columns

    cols_to_keep = ["date", "departement", "graph_id", "nbsinister", "burnedareaRoot", "time_intervention", 'ressource']
    if has_baseline:
        cols_to_keep.append(baseline_col)

    gt_df = res[cols_to_keep].copy()
    gt_df["num_zone"] = gt_df["graph_id"]
    gt_dfs[target] = gt_df
    target_cols[target] = target

"""print(f"Loaded {len(data_frames)} configurations.")
if data_frames:
    risk_all = pd.concat(data_frames.values(), ignore_index=True)
    print("risk_all shape:", risk_all.shape)"""
    
sftp.close()
ssh.close()
# Out:
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (publickey) failed.
# INFO:paramiko.transport:Authentication (publickey) failed.
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# GRU_search_full_10_0_all_one_ regression_pdegpd nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_flwki-id{departement} nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_flwk nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_weightedcrossentropy nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_wkloss nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_bceloss nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_fl nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ regression_cll nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ regression_ccllt-id{node}-nclusters{30} nbsinister
# Found 9 directories matching configuration.
# INFO:paramiko.transport.sftp:[chan 0] sftp session closed.

# %%
target_cols
# Out:
# {'nbsinister-quantile-5-Class-Dept': 'nbsinister-quantile-5-Class-Dept'}

# %%
import sys, pickle
from pathlib import Path

# Ensure GNN subdir is on the path so pickle can find forecasting_models classes
_gnn_path = str(Path('GNN').resolve())
if _gnn_path not in sys.path:
    sys.path.insert(0, _gnn_path)

# Load scorers — one per target, stored in path_baseline as scorer_<SimpleName>.pkl
_SCORER_NAMES = {
    "nbsinister": "Fire",
}

scorers = {}
for _target, _simple in _SCORER_NAMES.items():
    _scorer_path = path_baseline / f"scorer_{_simple}.pkl"
    if _scorer_path.exists():
        with open(_scorer_path, 'rb') as _f:
            scorers[_simple] = pickle.load(_f)
        print(f"Loaded scorer for '{_simple}' from {_scorer_path}")
    else:
        print(f"WARNING: scorer file not found: {_scorer_path}")

print(f"Scorers loaded: {list(scorers.keys())}")
# Out:
# Loaded scorer for 'Fire' from firemen/scorer_Fire.pkl
# Scorers loaded: ['Fire']

# %%
#td = all_data_frames['nbsinister-quantile-5-Class-Dept']['GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30}']
td = all_data_frames['nbsinister-quantile-5-Class-Dept']['GRU_search_full_10_0_all_one_classification_weightedcrossentropy']

td[td['num_zone'] == 0]['risk_score'].plot()
td[td['num_zone'] == 0]['nbsinister'].plot()
# Out:
# <Axes: >

# %%
scorers['Fire'].pair_mean_deltas
# Out:
# {(0, 1): 1.3754888429786654,
#  (1, 2): 1.3793914882239662,
#  (2, 3): 1.504936077836164,
#  (3, 4): 1.8337926841973564,
#  (0, 2): 2.7548803312026315,
#  (1, 3): 2.88432756606013,
#  (2, 4): 3.3387287620335204,
#  (0, 3): 4.2598164090387955,
#  (1, 4): 4.718120250257487,
#  (0, 4): 6.093609093236152}

# %%
import datetime as dt, numpy as np, pandas as pd
from sklearn.metrics import recall_score

def find_dates_between(start, end):
    import datetime as _dt
    d = _dt.datetime.strptime(start,'%Y-%m-%d').date()
    e = _dt.datetime.strptime(end,'%Y-%m-%d').date()
    res = []
    while d < e:
        res.append(d.strftime('%Y-%m-%d')); d += _dt.timedelta(days=1)
    return res

allDates = find_dates_between('2017-06-12', '2024-12-31')

all_target_results = {}
TARGETS      = ["nbsinister"]
SIMPLE_NAMES = {"nbsinister": "Fire"}

dfe_results_all = []
fwi_results_all = []

def _score(df, pred_col, target_col, sc):
    try:
        sh, sl, cov, adj, smc, _, _ = sc.evaluation_scoring(
            df[pred_col].astype(float), df[target_col].fillna(0),
            df['date'], df['num_zone'],
            df_spline=5, min_n=1, reference=False
        )
        rec = recall_score(df[target_col] > 0, df[pred_col] > 0, zero_division=0)
        return {
            'score_high': sh, 'score_low': sl, 'score_min_class': smc, 'recall': rec,
            **{f'score_k{k}': float(adj.get(k, float('nan'))) for k in [1,2,3,4]},
            **{f'coverage_k{k}': int(cov.get(k, 0)) for k in [1,2,3,4]},
        }
    except Exception as e:
        print(f"    Scoring error: {e}"); return None

def _fill(row, prefix, r):
    if r:
        for k in [1,2,3,4]:
            row[f'{prefix}SCORE_k{k}'] = r.get(f'score_k{k}', float('nan'))
        for key in ['score_high','score_low','score_min_class','recall']:
            row[f'{prefix}{key.upper()}'] = r.get(key, float('nan'))
    else:
        for k in [1,2,3,4]:
            row[f'{prefix}SCORE_k{k}'] = float('nan')
        for key in ['score_high','score_low','score_min_class','recall']:
            row[f'{prefix}{key.upper()}'] = float('nan')

def _compute_agg(curr_metrics, ref_metrics):
    if not curr_metrics or not ref_metrics: return float('nan')
    EPS = 1e-6
    u_vals = []
    keys = [f'score_k{k}' for k in [1,2,3,4]] + ['recall', 'score_min_class']
    for k in keys:
        sk = float(curr_metrics.get(k, 0))
        skr = float(ref_metrics.get(k, 0))
        denom = max(abs(skr) + EPS, 0.1)
        u = (np.tanh((sk - skr) / denom) + 1.0) / 2.0
        u_vals.append(max(u, EPS))
    U = np.exp(np.mean(np.log(u_vals)))
    return float(2.0 * U - 1.0)

def load_baseline_metrics(target_name, mode='fwi', dept_id=None):
    fname = f"{mode}_scores_{target_name}.csv"
    try:
        bdf = pd.read_csv(path_baseline / fname)
        if dept_id is not None:
             # Logic to filter by department if baseline CSV has it
             # For now we useDataset column as '2023' (global) as fallback
            row = bdf[bdf['Dataset'] == f'2023_{dept_id}']
        else:
             row = bdf[bdf['Dataset'] == '2023']
        if row.empty: return None
        data = row.iloc[0]
        res = {f'score_k{k}': data.get(f'k{k}', 0) for k in [1,2,3,4]}
        res['recall'] = data.get('recall', 0)
        res['score_min_class'] = data.get('min_class_score', 0)
        return res
    except: return None

print("Starting dual scoring (FWI 2023 / DFE 2023 summer) with per-department AGG scores...")

for target_key in TARGETS:
    matched_key = _INV_CLLT_TARGET_MAP[target_key]
    if matched_key not in all_data_frames.keys():
        print(f"Target {target_key} not found in all_data_frames"); continue

    simple_name = SIMPLE_NAMES[target_key]
    sc = scorers.get(simple_name)
    if sc is None:
        print(f"No scorer for {simple_name}  — skipping"); continue

    print(f"\n{'='*40}\n{simple_name} (sigma={sc.sigma:.4f})\n{'='*40}")
    ref_fwi_global = load_baseline_metrics(simple_name, 'fwi')
    ref_dfe_6      = load_baseline_metrics(simple_name, 'dfe')

    models_dict = all_data_frames[matched_key]
    gt_df_orig  = gt_dfs[matched_key].copy()
    gt_df_orig['date'] = gt_df_orig['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
    gt_df_orig['date'] = pd.to_datetime(gt_df_orig['date'])
    gt_df_orig['num_zone'] = gt_df_orig['num_zone'].astype(int)

    results_list = []
    for model_name, df_pred in models_dict.items():

        df_p = df_pred.copy()
        df_p['date'] = df_p['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
        df_p['date'] = pd.to_datetime(df_p['date'])
        df_p['num_zone'] = df_p['num_zone'].astype(int)

        gt_temp = gt_df_orig[['date','num_zone', target_key]].copy()
        merged  = pd.merge(df_p, gt_temp, on=['date','num_zone'], how='inner', suffixes=('','_gt'))
        merged = merged[merged['date'].dt.year == 2023]
        if merged.empty:
            print(f"  [{model_name}] empty merge for 2023 — skipped"); continue

        row_combined = {'Model': model_name, 'Target': simple_name}
        r_fwi_global = _score(merged, 'risk_score', target_key, sc)
        _fill(row_combined, 'FWI_Global_', r_fwi_global)
        row_combined['AGG_FWI_Global'] = _compute_agg(r_fwi_global, ref_fwi_global)
        
        all_depts = np.sort(merged['departement'].unique())
        for d_id in all_depts:
            m_dept = merged[merged['departement'] == d_id]
            r_fwi_d = _score(m_dept, 'risk_score', target_key, sc)
            ref_fwi_d = load_baseline_metrics(simple_name, 'fwi', d_id)
            _fill(row_combined, f'FWI_{int(d_id)}_', r_fwi_d)
            # Compute AGG per dept using global baseline as reference (or per-dept baseline if available later)
            row_combined[f'AGG_FWI_{int(d_id)}'] = _compute_agg(r_fwi_d, ref_fwi_d)

        dts = merged['date'].dt
        dept_mask = merged['departement'] == 6
        summer_mask = ((dts.month > 6) | ((dts.month == 6) & (dts.day >= 15))) & \
                      ((dts.month < 9) | ((dts.month == 9) & (dts.day <= 25)))

        merged_dfe = merged[summer_mask & dept_mask]
        r_dfe = _score(merged_dfe, 'risk_score', target_key, sc) if not merged_dfe.empty else None
        _fill(row_combined, 'DFE_6_', r_dfe)
        row_combined['AGG_DFE_6'] = _compute_agg(r_dfe, ref_dfe_6)
        
        fwi_results_all.append(row_combined.copy())
        if r_dfe:
            row_dfe = {'Model': model_name, 'Target': simple_name, 'AGG': row_combined['AGG_DFE_6']}
            row_dfe.update(r_dfe)
            dfe_results_all.append(row_dfe)
        results_list.append(row_combined)
        
    if results_list:
        df_res = pd.DataFrame(results_list).set_index('Model')
        all_target_results[simple_name] = {'scores_lh_plot': df_res}
        agg_cols = [c for c in df_res.columns if 'AGG' in c]
        print(df_res[agg_cols].head())

# Save outputs
if dfe_results_all:
    pd.DataFrame(dfe_results_all).to_csv('results_dfe_2023_v2.csv', index=False)
    print(f"\n Saved results_dfe_2023_v2.csv ({len(dfe_results_all)} rows)")
if fwi_results_all:
    pd.DataFrame(fwi_results_all).to_csv('results_fwi_2023_v2.csv', index=False)
    print(f" Saved results_fwi_2023_v2.csv ({len(fwi_results_all)} rows)")
print("\nDone.")
# Out:
# Starting dual scoring (FWI 2023 / DFE 2023 summer) with per-department AGG scores...
#
# ========================================
# Fire (sigma=0.7258)
# ========================================
#                                                     AGG_FWI_Global  AGG_FWI_1  \
# Model
# GRU_search_full_10_0_all_one_regression_pdegpd            0.226098   0.139132
# GRU_search_full_10_0_all_one_classification_flw...        0.445791   0.350488
# GRU_search_full_10_0_all_one_classification_flwk          0.618346   0.688511
# GRU_search_full_10_0_all_one_classification_wei...        0.090838   0.683426
# GRU_search_full_10_0_all_one_classification_wkloss        0.638213   0.680668
#
#                                                     AGG_FWI_6  AGG_FWI_25  \
# Model
# GRU_search_full_10_0_all_one_regression_pdegpd      -0.442723   -0.704627
# GRU_search_full_10_0_all_one_classification_flw...  -0.044902    0.619428
# GRU_search_full_10_0_all_one_classification_flwk    -0.014163    0.728721
# GRU_search_full_10_0_all_one_classification_wei...  -0.110679   -0.505501
# GRU_search_full_10_0_all_one_classification_wkloss   0.016413   -0.997599
#
#                                                     AGG_FWI_78  AGG_DFE_6
# Model
# GRU_search_full_10_0_all_one_regression_pdegpd        0.261866  -0.836877
# GRU_search_full_10_0_all_one_classification_flw...    0.384983  -0.183161
# GRU_search_full_10_0_all_one_classification_flwk      0.108321   0.012911
# GRU_search_full_10_0_all_one_classification_wei...   -0.882706  -0.079593
# GRU_search_full_10_0_all_one_classification_wkloss    0.582275  -0.428478
#
#  Saved results_dfe_2023_v2.csv (9 rows)
#  Saved results_fwi_2023_v2.csv (9 rows)
#
# Done.

# %%
# --- Per-Target comparison tables: Models vs FWI Baseline (2023, dept from MODE) ---
import pandas as pd
import numpy as np

# Département extrait depuis MODE ('06' -> 6)

dept = [1, 6, 25, 78, "Global"]

all_dept_tables = []
    
for d in dept:
    if d == 'Global':
        BASELINE_DATASET_KEY = f"2023"
    else:
        BASELINE_DATASET_KEY = f"2023_{d}"

    def load_fwi_baseline(target_name):
        """
        Load FWI baseline for target_name from path_baseline/fwi_scores_{target_name}.csv.
        Uses row Dataset == '2023_{DEPT}', fallback to 'Global'.
        Returns dict with score_k1..4, recall, score_min_class or None.
        """
        fname = path_baseline / f"fwi_scores_{target_name}.csv"
        try:
            bdf = pd.read_csv(fname)
        except FileNotFoundError:
            print(f"  baseline file not found: {fname}")
            return None
        row = bdf[bdf['Dataset'] == BASELINE_DATASET_KEY]
        if row.empty:
            row = bdf[bdf['Dataset'] == 'Global']
            if not row.empty:
                print(f"  [{target_name}] no row for {BASELINE_DATASET_KEY!r}, using 'Global'")
        if row.empty:
            print(f"  [{target_name}] no baseline row found (tried {BASELINE_DATASET_KEY!r} and 'Global')")
            return None

        data = row.iloc[0]
        return {
            'score_k1':       float(data.get('k1', np.nan)),
            'score_k2':       float(data.get('k2', np.nan)),
            'score_k3':       float(data.get('k3', np.nan)),
            'score_k4':       float(data.get('k4', np.nan)),
            'recall':         float(data.get('recall', np.nan)),
            'score_min_class': float(data.get('score_min_class', np.nan)),
        }

    def get_val(row, *candidates):
        for c in candidates:
            if c in row.index and pd.notna(row[c]):
                return float(row[c])
        return np.nan

    DISPLAY_COLS = [
        ('score_k1',        'k1'),
        ('score_k2',        'k2'),
        ('score_k3',        'k3'),
        ('score_k4',        'k4'),
        ('recall',          'recall'),
        ('score_min_class', 'min_class'),
        ('agg',             'AGG'),
    ]


    for target in ['Fire']:
        if target not in all_target_results:
            print(f"[{target}] not in all_target_results — skipping.")
            continue

        scores_lh = all_target_results[target].get('scores_lh_plot', pd.DataFrame())
        if scores_lh.empty:
            print(f"[{target}] scores_lh_plot empty — skipping.")
            continue

        ref = load_fwi_baseline(target)
        rows = []

        # --- Baseline row ---
        if ref:
            base_row = {'Model': f'Baseline FWI ({BASELINE_DATASET_KEY})'}
            for sk, label in DISPLAY_COLS:
                if sk == 'agg':
                    base_row[label] = np.nan
                else:
                    base_row[label] = ref.get(sk, np.nan)
            rows.append(base_row)
        else:
            print(f"  [{target}] baseline not loaded.")

        # --- Model rows ---
        for model_name, row in scores_lh.iterrows():
            model_row = {'Model': model_name}
            for sk, label in DISPLAY_COLS:
                if sk == 'agg':
                    val = get_val(row, f'AGG_FWI_{d}')
                elif sk == 'recall':
                    val = get_val(row, f'FWI_{d}_RECALL', 'RECALL')
                elif sk == 'score_min_class':
                    val = get_val(row, f'FWI_{d}_SCORE_MIN_CLASS', 'SCORE_MIN_CLASS')
                else:
                    k = sk[-1]
                    val = get_val(row,
                        f'FWI_{d}_SCORE_k{k}',
                        f'SCORE_k{k}',
                    )
                model_row[label] = val
            rows.append(model_row)

        df_table = pd.DataFrame(rows).set_index('Model')

        print(f"\n{'═'*65}")
        print(f"  {target}  —  baseline: {BASELINE_DATASET_KEY}")
        print(f"{'═'*65}")
        print(df_table.to_markdown(floatfmt=".4f"))
        print()

    if d != 'Global':
        all_dept_tables.append(df_table)
            
# --- Print Average Table ---
if all_dept_tables:
    df_avg = pd.concat(all_dept_tables).groupby('Model').mean()
    # Sort to keep the baseline at the top if it's there
    baseline_index = [i for i in df_avg.index if 'Baseline' in i]
    other_index = [i for i in df_avg.index if 'Baseline' not in i]
    df_avg = df_avg.reindex(baseline_index + other_index)
    
    print(f"\n{'═'*65}")
    print(f"  Fire  —  Average (Depts: 1, 6, 25, 78)")
    print(f"{'═'*65}")
    print(df_avg.to_markdown(floatfmt=".4f"))
    print()
# Out:
# ═════════════════════════════════════════════════════════════════
#   Fire  —  baseline: 2023_1
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |     k4 |   recall |   min_class |      AGG |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|-------:|---------:|------------:|---------:|
# | Baseline FWI (2023_1)                                                | -0.1409 | -0.1292 | -0.0376 | 0.1219 |   0.7834 |      1.0000 | nan      |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       |  0.3028 |  0.4732 |  0.0000 | 0.0000 |   0.6606 |      1.0000 |   0.1391 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -0.0326 |  0.0741 |  0.0875 | 0.0684 |   0.6931 |      1.0000 |   0.3505 |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.0733 |  0.0888 |  0.1349 | 0.2290 |   0.7437 |      1.0000 |   0.6885 |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     |  0.0560 |  0.0000 |  0.2428 | 0.2006 |   0.8592 |      1.0000 |   0.6834 |
# | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.1055 |  0.1701 |  0.2622 | 0.2222 |   0.6859 |      1.0000 |   0.6807 |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -0.1907 |  0.0000 |  0.0000 | 0.0000 |   0.8123 |      1.0000 |  -0.0403 |
# | GRU_search_full_10_0_all_one_classification_fl                       | -0.0722 |  0.0003 |  0.0270 | 0.0253 |   0.6318 |      1.0000 |   0.1413 |
# | GRU_search_full_10_0_all_one_regression_cll                          |  0.1396 |  0.1847 |  0.2281 | 0.0000 |   0.6282 |      1.0000 |   0.1992 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0239 |  0.0633 |  0.0805 | 0.0662 |   0.8881 |      1.0000 |   0.4208 |
#
#
# ═════════════════════════════════════════════════════════════════
#   Fire  —  baseline: 2023_6
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |     k3 |     k4 |   recall |   min_class |      AGG |
# |:---------------------------------------------------------------------|--------:|--------:|-------:|-------:|---------:|------------:|---------:|
# | Baseline FWI (2023_6)                                                | -0.0241 |  0.0014 | 0.0316 | 0.0995 |   0.7990 |      1.0000 | nan      |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       | -0.1691 |  0.0000 | 0.0000 | 0.0000 |   0.6961 |      1.0000 |  -0.4427 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.0650 |  0.0712 | 0.0000 | 0.0000 |   0.6601 |      1.0000 |  -0.0449 |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.0468 |  0.0755 | 0.0000 | 0.0000 |   0.8366 |      1.0000 |  -0.0142 |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     |  0.0048 |  0.0000 | 0.0000 | 0.0000 |   0.9379 |      1.0000 |  -0.1107 |
# | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.1154 |  0.2001 | 0.0000 | 0.0000 |   0.7124 |      1.0000 |   0.0164 |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -0.0075 |  0.0000 | 0.0000 | 0.0000 |   0.9265 |      1.0000 |  -0.1265 |
# | GRU_search_full_10_0_all_one_classification_fl                       | -0.1969 | -0.1176 | 0.0587 | 0.0000 |   0.6225 |      1.0000 |  -0.5873 |
# | GRU_search_full_10_0_all_one_regression_cll                          | -0.0279 |  0.0065 | 0.0000 | 0.0000 |   0.6601 |      1.0000 |  -0.1913 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0070 |  0.0188 | 0.0692 | 0.1809 |   0.9379 |      1.0000 |   0.4179 |
#
#
# ═════════════════════════════════════════════════════════════════
#   Fire  —  baseline: 2023_25
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|
# | Baseline FWI (2023_25)                                               |  0.0098 |  0.0655 |  0.0735 |  0.0000 |   0.6919 |      1.0000 | nan      |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       | -0.2779 | -0.0529 |  0.0000 |  0.0000 |   0.5657 |      1.0000 |  -0.7046 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.1363 |  0.1671 |  0.1922 |  0.1701 |   0.5354 |      1.0000 |   0.6194 |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.1912 |  0.2302 |  0.3593 |  0.6186 |   0.6162 |      1.0000 |   0.7287 |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | -0.1861 |  0.0000 |  0.0000 |  0.0000 |   0.8182 |      1.0000 |  -0.5055 |
# | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.1756 | -0.7416 | -0.8761 | -0.5837 |   0.5000 |      1.0000 |  -0.9976 |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -0.2299 |  0.0000 |  0.0000 |  0.0000 |   0.8030 |      1.0000 |  -0.5731 |
# | GRU_search_full_10_0_all_one_classification_fl                       | -0.0682 |  0.0612 |  0.0710 |  0.0613 |   0.5859 |      1.0000 |  -0.0267 |
# | GRU_search_full_10_0_all_one_regression_cll                          | -0.3223 | -0.1338 | -0.1301 |  0.0000 |   0.5303 |      1.0000 |  -0.8696 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0745 |  0.0928 |  0.1268 |  0.1640 |   0.8384 |      1.0000 |   0.5483 |
#
#
# ═════════════════════════════════════════════════════════════════
#   Fire  —  baseline: 2023_78
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |     k2 |     k3 |     k4 |   recall |   min_class |      AGG |
# |:---------------------------------------------------------------------|--------:|-------:|-------:|-------:|---------:|------------:|---------:|
# | Baseline FWI (2023_78)                                               | -0.0557 | 0.3837 | 0.4055 | 0.3596 |   0.6354 |      1.0000 | nan      |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       |  0.8328 | 1.0023 | 1.0478 | 0.0000 |   0.7293 |      1.0000 |   0.2619 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.1096 | 0.2998 | 0.6354 | 0.5145 |   0.6961 |      1.0000 |   0.3850 |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.1058 | 0.1302 | 0.2581 | 0.5034 |   0.8122 |      1.0000 |   0.1083 |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | -1.0267 | 0.0000 | 0.6723 | 0.4433 |   0.9116 |      1.0000 |  -0.8827 |
# | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.2249 | 0.4516 | 0.8057 | 0.6636 |   0.7182 |      1.0000 |   0.5823 |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -1.2508 | 0.0000 | 0.0000 | 0.0000 |   0.9171 |      1.0000 |  -0.9348 |
# | GRU_search_full_10_0_all_one_classification_fl                       |  0.0990 | 0.2802 | 0.5924 | 0.4775 |   0.7514 |      1.0000 |   0.3580 |
# | GRU_search_full_10_0_all_one_regression_cll                          |  0.3289 | 0.5262 | 0.6006 | 0.6227 |   0.6575 |      1.0000 |   0.5370 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0986 | 0.1240 | 0.2712 | 0.5739 |   0.9006 |      1.0000 |   0.1478 |
#
#
# ═════════════════════════════════════════════════════════════════
#   Fire  —  baseline: 2023
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |     k1 |     k2 |     k3 |     k4 |   recall |   min_class |      AGG |
# |:---------------------------------------------------------------------|-------:|-------:|-------:|-------:|---------:|------------:|---------:|
# | Baseline FWI (2023)                                                  | 0.1363 | 0.1401 | 0.1578 | 0.1727 |   0.7555 |      1.0000 | nan      |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       | 0.7369 | 0.8945 | 0.9792 | 0.0000 |   0.6727 |      1.0000 |   0.2261 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | 0.1824 | 0.2038 | 0.2534 | 0.3684 |   0.6530 |      1.0000 |   0.4458 |
# | GRU_search_full_10_0_all_one_classification_flwk                     | 0.2103 | 0.2447 | 0.3417 | 0.5070 |   0.7784 |      1.0000 |   0.6183 |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | 0.1019 | 0.0000 | 0.7075 | 0.5708 |   0.8983 |      1.0000 |   0.0908 |
# | GRU_search_full_10_0_all_one_classification_wkloss                   | 0.1984 | 0.3759 | 0.6356 | 0.5252 |   0.6743 |      1.0000 |   0.6382 |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | 0.0872 | 0.0000 | 0.0000 | 0.0000 |   0.8809 |      1.0000 |  -0.4762 |
# | GRU_search_full_10_0_all_one_classification_fl                       | 0.1485 | 0.1769 | 0.2182 | 0.3372 |   0.6372 |      1.0000 |   0.3285 |
# | GRU_search_full_10_0_all_one_regression_cll                          | 0.3266 | 0.3927 | 0.4962 | 0.5564 |   0.6325 |      1.0000 |   0.6984 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} | 0.1103 | 0.1296 | 0.2059 | 0.3458 |   0.9062 |      1.0000 |   0.2654 |
#
#
# ═════════════════════════════════════════════════════════════════
#   Fire  —  Average (Depts: 1, 6, 25, 78)
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |     k4 |   recall |   min_class |      AGG |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|-------:|---------:|------------:|---------:|
# | Baseline FWI (2023_1)                                                | -0.1409 | -0.1292 | -0.0376 | 0.1219 |   0.7834 |      1.0000 | nan      |
# | Baseline FWI (2023_25)                                               |  0.0098 |  0.0655 |  0.0735 | 0.0000 |   0.6919 |      1.0000 | nan      |
# | Baseline FWI (2023_6)                                                | -0.0241 |  0.0014 |  0.0316 | 0.0995 |   0.7990 |      1.0000 | nan      |
# | Baseline FWI (2023_78)                                               | -0.0557 |  0.3837 |  0.4055 | 0.3596 |   0.6354 |      1.0000 | nan      |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -0.4197 |  0.0000 |  0.0000 | 0.0000 |   0.8647 |      1.0000 |  -0.4187 |
# | GRU_search_full_10_0_all_one_classification_fl                       | -0.0596 |  0.0560 |  0.1873 | 0.1410 |   0.6479 |      1.0000 |  -0.0287 |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.1043 |  0.1312 |  0.1881 | 0.3377 |   0.7521 |      1.0000 |   0.3778 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.0696 |  0.1530 |  0.2288 | 0.1882 |   0.6462 |      1.0000 |   0.3275 |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | -0.2880 |  0.0000 |  0.2288 | 0.1610 |   0.8817 |      1.0000 |  -0.2039 |
# | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.1553 |  0.0201 |  0.0479 | 0.0755 |   0.6541 |      1.0000 |   0.0704 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0510 |  0.0747 |  0.1369 | 0.2462 |   0.8912 |      1.0000 |   0.3837 |
# | GRU_search_full_10_0_all_one_regression_cll                          |  0.0296 |  0.1459 |  0.1746 | 0.1557 |   0.6190 |      1.0000 |  -0.0812 |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       |  0.1722 |  0.3557 |  0.2619 | 0.0000 |   0.6629 |      1.0000 |  -0.1866 |

# %%
all_dept_tables
# Out:
# [                                                          k1        k2  \
#  Model
#  Baseline FWI (2023_1)                              -0.140872 -0.129175
#  GRU_search_full_10_0_all_one_regression_pdegpd      0.302815  0.473224
#  GRU_search_full_10_0_all_one_classification_flw... -0.032597  0.074122
#  GRU_search_full_10_0_all_one_classification_flwk    0.073304  0.088850
#  GRU_search_full_10_0_all_one_classification_wei...  0.055996  0.000000
#  GRU_search_full_10_0_all_one_classification_wkloss  0.105526  0.170084
#  GRU_search_full_10_0_all_one_classification_bce... -0.190742  0.000000
#  GRU_search_full_10_0_all_one_classification_fl     -0.072219  0.000273
#  GRU_search_full_10_0_all_one_regression_cll         0.139561  0.184737
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.023873  0.063260
#
#                                                            k3        k4  \
#  Model
#  Baseline FWI (2023_1)                              -0.037575  0.121905
#  GRU_search_full_10_0_all_one_regression_pdegpd      0.000000  0.000000
#  GRU_search_full_10_0_all_one_classification_flw...  0.087460  0.068395
#  GRU_search_full_10_0_all_one_classification_flwk    0.134918  0.229036
#  GRU_search_full_10_0_all_one_classification_wei...  0.242755  0.200599
#  GRU_search_full_10_0_all_one_classification_wkloss  0.262241  0.222174
#  GRU_search_full_10_0_all_one_classification_bce...  0.000000  0.000000
#  GRU_search_full_10_0_all_one_classification_fl      0.027046  0.025296
#  GRU_search_full_10_0_all_one_regression_cll         0.228066  0.000000
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.080491  0.066152
#
#                                                        recall  min_class  \
#  Model
#  Baseline FWI (2023_1)                               0.783394        1.0
#  GRU_search_full_10_0_all_one_regression_pdegpd      0.660650        1.0
#  GRU_search_full_10_0_all_one_classification_flw...  0.693141        1.0
#  GRU_search_full_10_0_all_one_classification_flwk    0.743682        1.0
#  GRU_search_full_10_0_all_one_classification_wei...  0.859206        1.0
#  GRU_search_full_10_0_all_one_classification_wkloss  0.685921        1.0
#  GRU_search_full_10_0_all_one_classification_bce...  0.812274        1.0
#  GRU_search_full_10_0_all_one_classification_fl      0.631769        1.0
#  GRU_search_full_10_0_all_one_regression_cll         0.628159        1.0
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.888087        1.0
#
#                                                           AGG
#  Model
#  Baseline FWI (2023_1)                                    NaN
#  GRU_search_full_10_0_all_one_regression_pdegpd      0.139132
#  GRU_search_full_10_0_all_one_classification_flw...  0.350488
#  GRU_search_full_10_0_all_one_classification_flwk    0.688511
#  GRU_search_full_10_0_all_one_classification_wei...  0.683426
#  GRU_search_full_10_0_all_one_classification_wkloss  0.680668
#  GRU_search_full_10_0_all_one_classification_bce... -0.040309
#  GRU_search_full_10_0_all_one_classification_fl      0.141291
#  GRU_search_full_10_0_all_one_regression_cll         0.199222
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.420751  ,
#                                                            k1        k2  \
#  Model
#  Baseline FWI (2023_6)                              -0.024135  0.001430
#  GRU_search_full_10_0_all_one_regression_pdegpd     -0.169140  0.000000
#  GRU_search_full_10_0_all_one_classification_flw...  0.064984  0.071168
#  GRU_search_full_10_0_all_one_classification_flwk    0.046776  0.075500
#  GRU_search_full_10_0_all_one_classification_wei...  0.004786  0.000000
#  GRU_search_full_10_0_all_one_classification_wkloss  0.115381  0.200076
#  GRU_search_full_10_0_all_one_classification_bce... -0.007530  0.000000
#  GRU_search_full_10_0_all_one_classification_fl     -0.196867 -0.117600
#  GRU_search_full_10_0_all_one_regression_cll        -0.027873  0.006494
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.007036  0.018760
#
#                                                            k3        k4  \
#  Model
#  Baseline FWI (2023_6)                               0.031583  0.099466
#  GRU_search_full_10_0_all_one_regression_pdegpd      0.000000  0.000000
#  GRU_search_full_10_0_all_one_classification_flw...  0.000000  0.000000
#  GRU_search_full_10_0_all_one_classification_flwk    0.000000  0.000000
#  GRU_search_full_10_0_all_one_classification_wei...  0.000000  0.000000
#  GRU_search_full_10_0_all_one_classification_wkloss  0.000000  0.000000
#  GRU_search_full_10_0_all_one_classification_bce...  0.000000  0.000000
#  GRU_search_full_10_0_all_one_classification_fl      0.058651  0.000000
#  GRU_search_full_10_0_all_one_regression_cll         0.000000  0.000000
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.069212  0.180858
#
#                                                        recall  min_class  \
#  Model
#  Baseline FWI (2023_6)                               0.799020        1.0
#  GRU_search_full_10_0_all_one_regression_pdegpd      0.696078        1.0
#  GRU_search_full_10_0_all_one_classification_flw...  0.660131        1.0
#  GRU_search_full_10_0_all_one_classification_flwk    0.836601        1.0
#  GRU_search_full_10_0_all_one_classification_wei...  0.937908        1.0
#  GRU_search_full_10_0_all_one_classification_wkloss  0.712418        1.0
#  GRU_search_full_10_0_all_one_classification_bce...  0.926471        1.0
#  GRU_search_full_10_0_all_one_classification_fl      0.622549        1.0
#  GRU_search_full_10_0_all_one_regression_cll         0.660131        1.0
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.937908        1.0
#
#                                                           AGG
#  Model
#  Baseline FWI (2023_6)                                    NaN
#  GRU_search_full_10_0_all_one_regression_pdegpd     -0.442723
#  GRU_search_full_10_0_all_one_classification_flw... -0.044902
#  GRU_search_full_10_0_all_one_classification_flwk   -0.014163
#  GRU_search_full_10_0_all_one_classification_wei... -0.110679
#  GRU_search_full_10_0_all_one_classification_wkloss  0.016413
#  GRU_search_full_10_0_all_one_classification_bce... -0.126483
#  GRU_search_full_10_0_all_one_classification_fl     -0.587308
#  GRU_search_full_10_0_all_one_regression_cll        -0.191266
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.417925  ,
#                                                            k1        k2  \
#  Model
#  Baseline FWI (2023_25)                              0.009769  0.065523
#  GRU_search_full_10_0_all_one_regression_pdegpd     -0.277858 -0.052916
#  GRU_search_full_10_0_all_one_classification_flw...  0.136308  0.167052
#  GRU_search_full_10_0_all_one_classification_flwk    0.191182  0.230173
#  GRU_search_full_10_0_all_one_classification_wei... -0.186141  0.000000
#  GRU_search_full_10_0_all_one_classification_wkloss  0.175565 -0.741582
#  GRU_search_full_10_0_all_one_classification_bce... -0.229876  0.000000
#  GRU_search_full_10_0_all_one_classification_fl     -0.068172  0.061174
#  GRU_search_full_10_0_all_one_regression_cll        -0.322277 -0.133830
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.074457  0.092795
#
#                                                            k3        k4  \
#  Model
#  Baseline FWI (2023_25)                              0.073482  0.000000
#  GRU_search_full_10_0_all_one_regression_pdegpd      0.000000  0.000000
#  GRU_search_full_10_0_all_one_classification_flw...  0.192218  0.170117
#  GRU_search_full_10_0_all_one_classification_flwk    0.359331  0.618559
#  GRU_search_full_10_0_all_one_classification_wei...  0.000000  0.000000
#  GRU_search_full_10_0_all_one_classification_wkloss -0.876127 -0.583733
#  GRU_search_full_10_0_all_one_classification_bce...  0.000000  0.000000
#  GRU_search_full_10_0_all_one_classification_fl      0.070973  0.061325
#  GRU_search_full_10_0_all_one_regression_cll        -0.130077  0.000000
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.126787  0.163994
#
#                                                        recall  min_class  \
#  Model
#  Baseline FWI (2023_25)                              0.691919        1.0
#  GRU_search_full_10_0_all_one_regression_pdegpd      0.565657        1.0
#  GRU_search_full_10_0_all_one_classification_flw...  0.535354        1.0
#  GRU_search_full_10_0_all_one_classification_flwk    0.616162        1.0
#  GRU_search_full_10_0_all_one_classification_wei...  0.818182        1.0
#  GRU_search_full_10_0_all_one_classification_wkloss  0.500000        1.0
#  GRU_search_full_10_0_all_one_classification_bce...  0.803030        1.0
#  GRU_search_full_10_0_all_one_classification_fl      0.585859        1.0
#  GRU_search_full_10_0_all_one_regression_cll         0.530303        1.0
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.838384        1.0
#
#                                                           AGG
#  Model
#  Baseline FWI (2023_25)                                   NaN
#  GRU_search_full_10_0_all_one_regression_pdegpd     -0.704627
#  GRU_search_full_10_0_all_one_classification_flw...  0.619428
#  GRU_search_full_10_0_all_one_classification_flwk    0.728721
#  GRU_search_full_10_0_all_one_classification_wei... -0.505501
#  GRU_search_full_10_0_all_one_classification_wkloss -0.997599
#  GRU_search_full_10_0_all_one_classification_bce... -0.573064
#  GRU_search_full_10_0_all_one_classification_fl     -0.026698
#  GRU_search_full_10_0_all_one_regression_cll        -0.869619
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.548265  ,
#                                                            k1        k2  \
#  Model
#  Baseline FWI (2023_78)                             -0.055720  0.383674
#  GRU_search_full_10_0_all_one_regression_pdegpd      0.832813  1.002322
#  GRU_search_full_10_0_all_one_classification_flw...  0.109607  0.299806
#  GRU_search_full_10_0_all_one_classification_flwk    0.105818  0.130214
#  GRU_search_full_10_0_all_one_classification_wei... -1.026695  0.000000
#  GRU_search_full_10_0_all_one_classification_wkloss  0.224887  0.451627
#  GRU_search_full_10_0_all_one_classification_bce... -1.250845  0.000000
#  GRU_search_full_10_0_all_one_classification_fl      0.099030  0.280192
#  GRU_search_full_10_0_all_one_regression_cll         0.328948  0.526242
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.098578  0.123952
#
#                                                            k3        k4  \
#  Model
#  Baseline FWI (2023_78)                              0.405451  0.359556
#  GRU_search_full_10_0_all_one_regression_pdegpd      1.047758  0.000000
#  GRU_search_full_10_0_all_one_classification_flw...  0.635411  0.514458
#  GRU_search_full_10_0_all_one_classification_flwk    0.258125  0.503388
#  GRU_search_full_10_0_all_one_classification_wei...  0.672250  0.443255
#  GRU_search_full_10_0_all_one_classification_wkloss  0.805666  0.663566
#  GRU_search_full_10_0_all_one_classification_bce...  0.000000  0.000000
#  GRU_search_full_10_0_all_one_classification_fl      0.592397  0.477530
#  GRU_search_full_10_0_all_one_regression_cll         0.600609  0.622725
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.271183  0.573950
#
#                                                        recall  min_class  \
#  Model
#  Baseline FWI (2023_78)                              0.635359        1.0
#  GRU_search_full_10_0_all_one_regression_pdegpd      0.729282        1.0
#  GRU_search_full_10_0_all_one_classification_flw...  0.696133        1.0
#  GRU_search_full_10_0_all_one_classification_flwk    0.812155        1.0
#  GRU_search_full_10_0_all_one_classification_wei...  0.911602        1.0
#  GRU_search_full_10_0_all_one_classification_wkloss  0.718232        1.0
#  GRU_search_full_10_0_all_one_classification_bce...  0.917127        1.0
#  GRU_search_full_10_0_all_one_classification_fl      0.751381        1.0
#  GRU_search_full_10_0_all_one_regression_cll         0.657459        1.0
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.900552        1.0
#
#                                                           AGG
#  Model
#  Baseline FWI (2023_78)                                   NaN
#  GRU_search_full_10_0_all_one_regression_pdegpd      0.261866
#  GRU_search_full_10_0_all_one_classification_flw...  0.384983
#  GRU_search_full_10_0_all_one_classification_flwk    0.108321
#  GRU_search_full_10_0_all_one_classification_wei... -0.882706
#  GRU_search_full_10_0_all_one_classification_wkloss  0.582275
#  GRU_search_full_10_0_all_one_classification_bce... -0.934806
#  GRU_search_full_10_0_all_one_classification_fl      0.357973
#  GRU_search_full_10_0_all_one_regression_cll         0.536962
#  GRU_search_full_10_0_all_one_regression_ccllt-i...  0.147786  ]

# %%
# --- Visualization: Top-2 Models by AGG score per Target ---
import pandas as pd
import matplotlib.pyplot as plt

dept = [1, 6, 25, 78]

for d in dept:
        
    # We iterate over the simple names used in all_target_results
    for simple_name in ['Fire']:
        if simple_name not in all_target_results:
            print(f"[{simple_name}] not found in all_target_results — skipping visualization.")
            continue
        
        res = all_target_results[simple_name]
        df_res = res.get('scores_lh_plot', pd.DataFrame())
        if df_res.empty: continue
        
        # Selection of top 2 models by AGG
        agg_candidates = [c for c in df_res.columns if 'AGG' in c]
        if not agg_candidates: continue
        
        agg_col = f'AGG_FWI_{d}'
        
        # Identify top 2 models
        top_models = df_res.sort_values(agg_col, ascending=False).head(2)
        
        print(f"\n{'='*70}\n  VISUALIZING TOP-2 MODELS FOR: {simple_name} (sorted by {agg_col})\n{'='*70}")
        
        sc = scorers.get(simple_name)
        if sc is None:
            print(f"Scorer not found for {simple_name}"); continue
        
        # Find the short_key from SIMPLE_NAMES inverse
        short_key = None
        for k, v in SIMPLE_NAMES.items():
            if v == simple_name:
                short_key = k
                break
        
        # Use _INV_CLLT_TARGET_MAP to get target_key (long name)
        target_key = _INV_CLLT_TARGET_MAP.get(short_key)
        if target_key is None or target_key not in gt_dfs:
            print(f"Ground truth link not found for {simple_name} (short_key: {short_key})"); continue

        gt_df_orig = gt_dfs[target_key].copy()
        gt_df_orig = gt_df_orig[gt_df_orig['departement'] == d]
        gt_df_orig['date'] = gt_df_orig['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
        gt_df_orig['date'] = pd.to_datetime(gt_df_orig['date'])
        gt_df_orig['num_zone'] = gt_df_orig['num_zone'].astype(int)

        for model_name, row in top_models.iterrows():
            print(f"\n>>> Plotting Fit for {model_name} (AGG: {row[agg_col]:.4f})")
            
            # Get predictions
            models_dict = all_data_frames.get(target_key, {})
            df_pred = models_dict.get(model_name)
            if df_pred is None:
                print(f"  Predictions not found for {model_name}"); continue
            
            df_p = df_pred.copy()
            df_p['date'] = df_p['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
            df_p['date'] = pd.to_datetime(df_p['date'])
            df_p['num_zone'] = df_p['num_zone'].astype(int)

            # Merge for scoring. Use suffixes to avoid renaming the model's prediction columns.
            # We need the ground truth from gt_df_orig, so we take it from the '_gt' columns.
            merged = pd.merge(df_p, gt_df_orig, on=['date', 'num_zone'], how='inner', suffixes=('', '_gt'))
            merged = merged[merged['date'].dt.year == 2023]

            if not merged.empty:
                # Use target_key_gt as the ground truth classes for the scorer
                # Use risk_score as the model's predicted risk class
                sc._plot(merged['risk_score'], merged[f"{target_key}_gt"], merged['date'], merged['num_zone'], 
                        title=f"{simple_name} Monotonic Fit - {model_name} - dept {d}")
            else:
                print("  Empty merge for 2023 data — check date alignment.")
# Out:
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Fire (sorted by AGG_FWI_1)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_classification_flwk (AGG: 0.6885)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_classification_weightedcrossentropy (AGG: 0.6834)
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Fire (sorted by AGG_FWI_6)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: 0.4179)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_classification_wkloss (AGG: 0.0164)
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Fire (sorted by AGG_FWI_25)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_classification_flwk (AGG: 0.7287)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_classification_flwki-id{departement} (AGG: 0.6194)
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Fire (sorted by AGG_FWI_78)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_classification_wkloss (AGG: 0.5823)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_cll (AGG: 0.5370)

# %%
# --- DFE comparison tables: Models vs DFE Baseline (été 2023, dept 06) ---
# DFE = Défense des Forêts contre l'Incendie, subset: été 2023 (mid-juin → fin sept), dept 6

import pandas as pd
import numpy as np

DFE_YEAR = "2023"   # Dataset key in dfe_scores_*.csv

def load_dfe_baseline(target_name):
    """
    Load DFE baseline from path_baseline/dfe_scores_{target_name}.csv.
    Uses row Dataset == DFE_YEAR, fallback to 'Global'.
    """
    fname = path_baseline / f"dfe_scores_{target_name}.csv"
    try:
        bdf = pd.read_csv(fname)
    except FileNotFoundError:
        print(f"  DFE baseline file not found: {fname}")
        return None

    row = bdf[bdf['Dataset'] == DFE_YEAR]
    if row.empty:
        row = bdf[bdf['Dataset'] == 'Global']
        if not row.empty:
            print(f"  [{target_name}] no DFE row for {DFE_YEAR!r}, using 'Global'")
    if row.empty:
        print(f"  [{target_name}] no DFE baseline found")
        return None

    data = row.iloc[0]
    return {
        'score_k1':        float(data.get('k1', np.nan)),
        'score_k2':        float(data.get('k2', np.nan)),
        'score_k3':        float(data.get('k3', np.nan)),
        'score_k4':        float(data.get('k4', np.nan)),
        'recall':          float(data.get('recall', np.nan)),
        'score_min_class': float(data.get('score_min_class', np.nan)),
    }


def get_val(row, *candidates):
    for c in candidates:
        if c in row.index and pd.notna(row[c]):
            return float(row[c])
    return np.nan


DISPLAY_COLS = [
    ('score_k1',        'k1'),
    ('score_k2',        'k2'),
    ('score_k3',        'k3'),
    ('score_k4',        'k4'),
    ('recall',          'recall'),
    ('score_min_class', 'min_class'),
    ('agg',             'AGG_DFE'),
]

for target in ['Fire', 'Time', 'Ressource']:
    if target not in all_target_results:
        print(f"[{target}] not in all_target_results — skipping.")
        continue

    scores_lh = all_target_results[target].get('scores_lh_plot', pd.DataFrame())
    if scores_lh.empty:
        print(f"[{target}] scores_lh_plot empty — skipping.")
        continue

    ref = load_dfe_baseline(target)
    rows = []

    # --- Baseline row ---
    if ref:
        base_row = {'Model': f'Baseline DFE ({DFE_YEAR})'}
        for sk, label in DISPLAY_COLS:
            if sk == 'agg':
                base_row[label] = np.nan
            else:
                base_row[label] = ref.get(sk, np.nan)
        rows.append(base_row)

    # --- Model rows ---
    for model_name, row in scores_lh.iterrows():
        model_row = {'Model': model_name}
        for sk, label in DISPLAY_COLS:
            if sk == 'agg':
                # DFE AGG = summer dept 6 AGG
                val = get_val(row, 'AGG_DFE_6', 'AGG_DFE', 'AGG')
            elif sk == 'recall':
                val = get_val(row, 'DFE_6_RECALL', 'FWI_Global_RECALL', 'RECALL')
            elif sk == 'score_min_class':
                val = get_val(row, 'DFE_6_SCORE_MIN_CLASS', 'FWI_Global_SCORE_MIN_CLASS')
            else:
                k = sk[-1]
                val = get_val(row,
                    f'DFE_6_SCORE_k{k}',
                    f'FWI_Global_SCORE_k{k}',
                    f'SCORE_k{k}',
                )
            model_row[label] = val
        rows.append(model_row)

    df_table = pd.DataFrame(rows).set_index('Model')

    print(f"\n{'═'*65}")
    print(f"  {target}  —  DFE été {DFE_YEAR}, dept 6")
    print(f"{'═'*65}")
    print(df_table.to_markdown(floatfmt=".4f"))
    print()
# Out:
# ═════════════════════════════════════════════════════════════════
#   Fire  —  DFE été 2023, dept 6
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |     k3 |     k4 |   recall |   min_class |   AGG_DFE |
# |:---------------------------------------------------------------------|--------:|--------:|-------:|-------:|---------:|------------:|----------:|
# | Baseline DFE (2023)                                                  |  0.0160 |  0.0225 | 0.0441 | 0.0668 |   0.8563 |      1.0000 |  nan      |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       | -0.5024 |  0.0000 | 0.0000 | 0.0000 |   0.6724 |      1.0000 |   -0.8369 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -0.0007 |  0.0222 | 0.0000 | 0.0000 |   0.6207 |      1.0000 |   -0.1832 |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.0628 |  0.0927 | 0.0000 | 0.0000 |   0.8218 |      1.0000 |    0.0129 |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     |  0.0661 |  0.0000 | 0.0000 | 0.0000 |   0.9368 |      1.0000 |   -0.0796 |
# | GRU_search_full_10_0_all_one_classification_wkloss                   | -0.1640 |  0.1795 | 0.0000 | 0.0000 |   0.5920 |      1.0000 |   -0.4285 |
# | GRU_search_full_10_0_all_one_classification_bceloss                  |  0.0533 |  0.0000 | 0.0000 | 0.0000 |   0.9540 |      1.0000 |   -0.0883 |
# | GRU_search_full_10_0_all_one_classification_fl                       | -0.4689 |  0.2384 | 0.1110 | 0.0000 |   0.5805 |      1.0000 |   -0.7543 |
# | GRU_search_full_10_0_all_one_regression_cll                          | -0.1225 |  0.0521 | 0.0000 | 0.0000 |   0.5632 |      1.0000 |   -0.3937 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} | -0.0221 | -0.0101 | 0.0691 | 0.2209 |   0.9540 |      1.0000 |    0.1502 |
#
# [Time] not in all_target_results — skipping.
# [Ressource] not in all_target_results — skipping.

# %%
# --- Visualization: Top-2 Models by AGG score per Target ---
import pandas as pd
import matplotlib.pyplot as plt

# We iterate over the simple names used in all_target_results
for simple_name in ['Fire', 'Time', 'Ressource']:
    if simple_name not in all_target_results:
        print(f"[{simple_name}] not found in all_target_results — skipping visualization.")
        continue
    
    res = all_target_results[simple_name]
    df_res = res.get('scores_lh_plot', pd.DataFrame())
    if df_res.empty: continue
    
    # Selection of top 2 models by AGG
    agg_candidates = [c for c in df_res.columns if 'AGG' in c]
    if not agg_candidates: continue
    
    agg_col = 'AGG_DFE_6' if 'AGG_DFE_6' in df_res.columns else agg_candidates[0]
    
    # Identify top 2 models
    top_models = df_res.sort_values(agg_col, ascending=False).head(2)
    
    print(f"\n{'='*70}\n  VISUALIZING TOP-2 MODELS FOR: {simple_name} (sorted by {agg_col})\n{'='*70}")
    
    sc = scorers.get(simple_name)
    if sc is None:
        print(f"Scorer not found for {simple_name}"); continue
    
    # Find the short_key from SIMPLE_NAMES inverse
    short_key = None
    for k, v in SIMPLE_NAMES.items():
        if v == simple_name:
            short_key = k
            break
    
    # Use _INV_CLLT_TARGET_MAP to get target_key (long name)
    target_key = _INV_CLLT_TARGET_MAP.get(short_key)
    if target_key is None or target_key not in gt_dfs:
        print(f"Ground truth link not found for {simple_name} (short_key: {short_key})"); continue

    gt_df_orig = gt_dfs[target_key].copy()
    gt_df_orig['date'] = gt_df_orig['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
    gt_df_orig['date'] = pd.to_datetime(gt_df_orig['date'])
    gt_df_orig['num_zone'] = gt_df_orig['num_zone'].astype(int)

    for model_name, row in top_models.iterrows():
        print(f"\n>>> Plotting Fit for {model_name} (AGG: {row[agg_col]:.4f})")
        
        # Get predictions
        models_dict = all_data_frames.get(target_key, {})
        df_pred = models_dict.get(model_name)
        if df_pred is None:
            print(f"  Predictions not found for {model_name}"); continue
        
        df_p = df_pred.copy()
        df_p['date'] = df_p['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
        df_p['date'] = pd.to_datetime(df_p['date'])
        df_p['num_zone'] = df_p['num_zone'].astype(int)

        # Merge for scoring. Use suffixes to avoid renaming the model's prediction columns.
        # We need the ground truth from gt_df_orig, so we take it from the '_gt' columns.
        merged = pd.merge(df_p, gt_df_orig, on=['date', 'num_zone'], how='inner', suffixes=('', '_gt'))
        merged = merged[merged['date'].dt.year == 2023]

        if not merged.empty:
            # Use target_key_gt as the ground truth classes for the scorer
            # Use risk_score as the model's predicted risk class
            sc._plot(merged['risk_score'], merged[f"{target_key}_gt"], merged['date'], merged['num_zone'], 
                    title=f"{simple_name} Monotonic Fit - {model_name}")
        else:
            print("  Empty merge for 2023 data — check date alignment.")
# Out:
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Fire (sorted by AGG_DFE_6)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: 0.1502)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_classification_flwk (AGG: 0.0129)
# [Time] not found in all_target_results — skipping visualization.
# [Ressource] not found in all_target_results — skipping visualization.
