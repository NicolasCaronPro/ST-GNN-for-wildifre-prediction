# %%
import sys
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import logging
from patsy import bs
import itertools

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
# Configuration

MODE = 'firemen2'
year_test = "2023"

if MODE == '06':
    base_path = Path('firemen/firepoint/2x2/test/occurence_062023/all/full_all_3_0_zonemeteo_node/')
    parent_dir_name = 'full_all_3_0_zonemeteo_node/'
    path_baseline = Path('06/')
elif MODE == 'bdiff':
    pass
elif MODE == 'firemen2':
    base_path = Path('firemen/firepoint/2x2/test/occurence_01_06_25/all/full_all_3_0_risk-size-zonemeteo-degree-a3-r5-t0.3_node/')
    parent_dir_name = 'full_all_3_0_risk-size-zonemeteo-degree-a3-r5-t0.3_node/'
    path_baseline = Path('firemen2/')

scale = 10
horizon = 0

clustering = 'quantile'

models = [
    'GRU_search_full_10_0_all_one_',
    #'GRUAtt_search_full_10_0_all_one_',
]

losses = [
    'regression_pdegpd',
    'classification_flwki-id{departement}',
    'classification_flwk',
    'classification_weightedcrossentropy',
    'classification_wkloss',
    'classification_bceloss',
    'classification_fl',
    'regression_cll',
]

targets = [
   f'nbsinister-{clustering}-5-Class-Dept',
   f'timeintervention-{clustering}-5-Class-Dept',
   f'ressource-{clustering}-5-Class-Dept',
]

all_dir = list(itertools.product(models, losses, targets))

loss_2 = ["regression_ccllt-id{node}-nclusters{30}"]
targets_2 = ["nbsinister", 'ressource', "timeintervention"]

all_dir_2 = list(itertools.product(models, loss_2, targets_2))

all_dir = all_dir + all_dir_2

# %%
TARGET_MAP = {
    "nbsinister-quantile-5-Class-Dept": "nbsinister",
    "timeintervention-quantile-5-Class-Dept": "time_intervention",
    "ressource-quantile-5-Class-Dept": "ressource",
}

_INV_CLLT_TARGET_MAP = {v: k for k, v in TARGET_MAP.items()}

# %%
import os
import io
import pandas as pd
import paramiko

def list_remote_pkl_files(sftp, remote_dir):
    pkl_files = []

    # 1) essayer remote_dir/H0/*.pkl
    h0_dir = remote_dir.rstrip("/") + "/H0"
    try:
        for f in sftp.listdir(h0_dir):
            if f.endswith(".pkl"):
                pkl_files.append(h0_dir + "/" + f)
    except FileNotFoundError:
        pass

    # 2) sinon remote_dir/*.pkl
    if not pkl_files:
        try:
            for f in sftp.listdir(remote_dir):
                if f.endswith(".pkl"):
                    pkl_files.append(remote_dir.rstrip("/") + "/" + f)
        except FileNotFoundError:
            pass

    return pkl_files

def read_remote_pickle(sftp, remote_file_path):
    # Lire le fichier distant dans un buffer mémoire puis le donner à pandas
    with sftp.open(remote_file_path, "rb") as f:
        data = f.read()
    return pd.read_pickle(io.BytesIO(data))

def find_remote_directories(sftp, base_path_remote, all_dir):
    matches = []

    # Vérifie que base_path_remote existe
    try:
        sftp.listdir(base_path_remote)
    except FileNotFoundError:
        print(f"Base path does not exist on remote: {base_path_remote}")
        return []

    for (model, loss, target) in all_dir:
        print(model, loss, target)
        dir_name = f"{model}{target}_{loss}"
        full_path = base_path_remote.rstrip("/") + "/" + dir_name
        try:
            # Si listdir marche, c'est un dossier existant
            sftp.listdir(full_path)
            matches.append((full_path, model, loss, target))
        except FileNotFoundError:
            continue

    return matches

TARGET_MAP = {
    "nbsinister-quantile-5-Class-Dept": "nbsinister",
    "timeintervention-quantile-5-Class-Dept": "time_intervention",
    "ressource-quantile-5-Class-Dept": "ressource",
}

_INV_CLLT_TARGET_MAP = {v: k for k, v in TARGET_MAP.items()}

# --- Connexion SSH ---
hostname = "mesohelios1.univ-fcomte.fr"
username = "ncaron"
password = "xp2nrfeu"
#key_path = "/chemin/vers/id_rsa"  # si clé

ssh = paramiko.SSHClient()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
ssh.connect(hostname, username=username, password=password)

sftp = ssh.open_sftp()

# --- Utilisation ---
base_path_remote = (Path("/Home/Users/ncaron/WORK/GNN") / base_path).as_posix()
directories = find_remote_directories(sftp, base_path_remote, all_dir)
print(f"Found {len(directories)} directories matching configuration.")

all_data_frames = {}
gt_dfs = {}
target_cols = {}

for d, model, loss, target in directories:

    if target not in all_data_frames.keys():
        all_data_frames[target] = {}
    if target is None:
        continue

    pkl_files = list_remote_pkl_files(sftp, d)
    if not pkl_files:
        continue

    file_path = pkl_files[0]
    
    try:
        res = read_remote_pickle(sftp, file_path)
    except Exception as e:
        print(f"Error loading {d}: {e}")
        continue

    if target in ["ressource", "timeintervention", "nbsinister"]:
        if target == "timeintervention":
            target = _INV_CLLT_TARGET_MAP["time_intervention"]
        else:
            target = _INV_CLLT_TARGET_MAP[target]

    if "date" not in res.columns or "graph_id" not in res.columns:
        print(f"Skipping {d}: missing date or graph_id")
        continue

    pred_col = f"prediction_{target}_0"
    if pred_col not in res.columns:
        if target in res.columns:
            pred_col = target
        else:
            print(f"Skipping {d}: no prediction column")
            continue

    df = res[["date", "departement", "graph_id", target]].copy()
    df["risk_score"] = res[pred_col]
    df[pred_col] = res[pred_col]
    df["config"] = f"{model}{loss}"
    
    if "nbsinister" in target:
        df["nbsinister"] = res["nbsinister"]
    elif "ressource" in target:
        df['ressource'] = res['ressource']
    elif 'time' in target:
        df["time_intervention"] = res['time_intervention']
    else:
        df["burnedareaRoot"] = res["burnedareaRoot"]
        
    df["num_zone"] = df["graph_id"]
    all_data_frames[target][f"{model}{loss}"] = df
    
    baseline_col = f"{target}"
    has_baseline = baseline_col in res.columns

    cols_to_keep = ["date", "departement", "graph_id", "nbsinister", "burnedareaRoot", "time_intervention", 'ressource']
    if has_baseline:
        cols_to_keep.append(baseline_col)

    gt_df = res[cols_to_keep].copy()
    gt_df["num_zone"] = gt_df["graph_id"]
    gt_dfs[target] = gt_df
    target_cols[target] = target

"""print(f"Loaded {len(data_frames)} configurations.")
if data_frames:
    risk_all = pd.concat(data_frames.values(), ignore_index=True)
    print("risk_all shape:", risk_all.shape)"""
    
sftp.close()
ssh.close()
# Out:
# INFO:paramiko.transport:Connected (version 2.0, client OpenSSH_8.0)
# INFO:paramiko.transport:Authentication (publickey) failed.
# INFO:paramiko.transport:Authentication (publickey) failed.
# INFO:paramiko.transport:Authentication (password) successful!
# INFO:paramiko.transport.sftp:[chan 0] Opened sftp connection (server version 3)
# GRU_search_full_10_0_all_one_ regression_pdegpd nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ regression_pdegpd timeintervention-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ regression_pdegpd ressource-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_flwki-id{departement} nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_flwki-id{departement} timeintervention-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_flwki-id{departement} ressource-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_flwk nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_flwk timeintervention-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_flwk ressource-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_weightedcrossentropy nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_weightedcrossentropy timeintervention-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_weightedcrossentropy ressource-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_wkloss nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_wkloss timeintervention-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_wkloss ressource-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_bceloss nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_bceloss timeintervention-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_bceloss ressource-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_fl nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_fl timeintervention-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ classification_fl ressource-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ regression_cll nbsinister-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ regression_cll timeintervention-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ regression_cll ressource-quantile-5-Class-Dept
# GRU_search_full_10_0_all_one_ regression_ccllt-id{node}-nclusters{30} nbsinister
# GRU_search_full_10_0_all_one_ regression_ccllt-id{node}-nclusters{30} ressource
# GRU_search_full_10_0_all_one_ regression_ccllt-id{node}-nclusters{30} timeintervention
# Found 23 directories matching configuration.
# INFO:paramiko.transport.sftp:[chan 0] sftp session closed.

# %%
all_data_frames.keys()
# Out:
# dict_keys(['nbsinister-quantile-5-Class-Dept', 'timeintervention-quantile-5-Class-Dept', 'ressource-quantile-5-Class-Dept', 'nbsinister', 'ressource', 'timeintervention'])

# %%
target_cols
# Out:
# {'nbsinister-quantile-5-Class-Dept': 'nbsinister-quantile-5-Class-Dept',
#  'timeintervention-quantile-5-Class-Dept': 'timeintervention-quantile-5-Class-Dept',
#  'ressource-quantile-5-Class-Dept': 'ressource-quantile-5-Class-Dept'}

# %%
import sys, pickle
from pathlib import Path

# Ensure GNN subdir is on the path so pickle can find forecasting_models classes
_gnn_path = str(Path('GNN').resolve())
if _gnn_path not in sys.path:
    sys.path.insert(0, _gnn_path)

# Load scorers — one per target, stored in path_baseline as scorer_<SimpleName>.pkl
_SCORER_NAMES = {
    "nbsinister": "Fire",
    "ressource": "Ressource",
    "timeintervention": "Time",
}

scorers = {}
for _target, _simple in _SCORER_NAMES.items():
    _scorer_path = path_baseline / f"scorer_{_simple}.pkl"
    if _scorer_path.exists():
        with open(_scorer_path, 'rb') as _f:
            scorers[_simple] = pickle.load(_f)
        print(f"Loaded scorer for '{_simple}' from {_scorer_path}")
    else:
        print(f"WARNING: scorer file not found: {_scorer_path}")

print(f"Scorers loaded: {list(scorers.keys())}")
# Out:
# Loaded scorer for 'Fire' from firemen2/scorer_Fire.pkl
# Loaded scorer for 'Ressource' from firemen2/scorer_Ressource.pkl
# Loaded scorer for 'Time' from firemen2/scorer_Time.pkl
# Scorers loaded: ['Fire', 'Ressource', 'Time']

# %%
#td = all_data_frames['nbsinister-quantile-5-Class-Dept']['GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30}']
#td = all_data_frames['nbsinister-quantile-5-Class-Dept']['GRU_search_full_10_0_all_one_classification_weightedcrossentropy']

#td[td['num_zone'] == 0]['risk_score'].plot()
#td[td['num_zone'] == 0]['nbsinister'].plot()

# %%
scorers['Fire'].pair_mean_deltas
# Out:
# {(0, 1): 1.3754888429786645,
#  (1, 2): 1.379391488223967,
#  (2, 3): 1.504936077836164,
#  (3, 4): 1.8337926841973564,
#  (0, 2): 2.7548803312026315,
#  (1, 3): 2.884327566060131,
#  (2, 4): 3.3387287620335204,
#  (0, 3): 4.2598164090387955,
#  (1, 4): 4.7181202502574875,
#  (0, 4): 6.093609093236152}

# %%
import datetime as dt, numpy as np, pandas as pd
from sklearn.metrics import recall_score

def find_dates_between(start, end):
    import datetime as _dt
    d = _dt.datetime.strptime(start,'%Y-%m-%d').date()
    e = _dt.datetime.strptime(end,'%Y-%m-%d').date()
    res = []
    while d < e:
        res.append(d.strftime('%Y-%m-%d')); d += _dt.timedelta(days=1)
    return res

allDates = find_dates_between('2017-06-12', '2024-12-31')

all_target_results = {}
TARGETS      = ["nbsinister", "ressource", "time_intervention"]
SIMPLE_NAMES = {"nbsinister": "Fire", "ressource" : "Ressource", "time_intervention": "Time"}

dfe_results_all = []
fwi_results_all = []
fwi_summer_results_all = []

def _score(df, pred_col, target_col, sc):
    try:
        sh, sl, cov, adj, smc, _, _ = sc.evaluation_scoring(
            df[pred_col].astype(float), df[target_col].fillna(0),
            df['date'], df['num_zone'],
            df_spline=5, min_n=1, reference=False
        )
        rec = recall_score(df[target_col] > 0, df[pred_col] > 0, zero_division=0)
        return {
            'score_high': sh, 'score_low': sl, 'score_min_class': smc, 'recall': rec,
            **{f'score_k{k}': float(adj.get(k, float('nan'))) for k in [1,2,3,4]},
            **{f'coverage_k{k}': int(cov.get(k, 0)) for k in [1,2,3,4]},
        }
    except Exception as e:
        print(f"    Scoring error: {e}"); return None

def _fill(row, prefix, r):
    if r:
        for k in [1,2,3,4]:
            row[f'{prefix}SCORE_k{k}'] = r.get(f'score_k{k}', float('nan'))
        for key in ['score_high','score_low','score_min_class','recall']:
            row[f'{prefix}{key.upper()}'] = r.get(key, float('nan'))
    else:
        for k in [1,2,3,4]:
            row[f'{prefix}SCORE_k{k}'] = float('nan')
        for key in ['score_high','score_low','score_min_class','recall']:
            row[f'{prefix}{key.upper()}'] = float('nan')

def _compute_agg(curr_metrics, ref_metrics):
    if not curr_metrics or not ref_metrics: return float('nan')
    EPS = 1e-6
    u_vals = []
    keys = [f'score_k{k}' for k in [1,2,3,4]] + ['recall', 'score_min_class']
    for k in keys:
        sk = float(curr_metrics.get(k, 0))
        skr = float(ref_metrics.get(k, 0))
        denom = max(abs(skr) + EPS, 0.1)
        u = (np.tanh((sk - skr) / denom) + 1.0) / 2.0
        u_vals.append(max(u, EPS))
    #U = np.exp(np.mean(np.log(u_vals)))
    U = np.mean(u_vals)    
    return float(2.0 * U - 1.0)

def load_baseline_metrics(target_name, mode='fwi', dept_id=None):
    fname = f"{mode}_scores_{target_name}.csv"
    try:
        bdf = pd.read_csv(path_baseline / fname)
        if dept_id is not None:
             # Logic to filter by department if baseline CSV has it
             # For now we useDataset column as '2023' (global) as fallback
            row = bdf[bdf['Dataset'] == f'{year_test}_{dept_id}']
        else:
             row = bdf[bdf['Dataset'] == f'{year_test}']
        if row.empty: return None
        data = row.iloc[0]
        res = {f'score_k{k}': data.get(f'k{k}', 0) for k in [1,2,3,4]}
        res['recall'] = data.get('recall', 0)
        res['score_min_class'] = data.get('score_min_class', 0)
        return res
    except: return None

print("Starting dual scoring (FWI 2023 / DFE 2023 summer) with per-department AGG scores...")

for target_key in TARGETS:
    matched_key = _INV_CLLT_TARGET_MAP[target_key]
    if matched_key not in all_data_frames.keys():
        print(f"Target {target_key} not found in all_data_frames"); continue

    simple_name = SIMPLE_NAMES[target_key]
    sc = scorers.get(simple_name)
    if sc is None:
        print(f"No scorer for {simple_name}  — skipping"); continue

    print(f"\n{'='*40}\n{simple_name} (sigma={sc.sigma:.4f})\n{'='*40}")
    ref_fwi_global = load_baseline_metrics(simple_name, 'fwi')
    ref_dfe_6      = load_baseline_metrics(simple_name, 'dfe')

    models_dict = all_data_frames[matched_key]
    gt_df_orig  = gt_dfs[matched_key].copy()
    gt_df_orig['date'] = gt_df_orig['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
    gt_df_orig['date'] = pd.to_datetime(gt_df_orig['date'])
    gt_df_orig['num_zone'] = gt_df_orig['num_zone'].astype(int)

    results_list = []
    for model_name, df_pred in models_dict.items():

        # FWI
        df_p = df_pred.copy()
        df_p['date'] = df_p['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
        df_p['date'] = pd.to_datetime(df_p['date'])
        df_p['num_zone'] = df_p['num_zone'].astype(int)

        gt_temp = gt_df_orig[['date','num_zone', target_key]].copy()
        merged  = pd.merge(df_p, gt_temp, on=['date','num_zone'], how='inner', suffixes=('','_gt'))
        merged = merged[merged['date'].dt.year == int(year_test)]
        if merged.empty:
            print(f"  [{model_name}] empty merge for {year_test} — skipped"); continue

        row_combined = {'Model': model_name, 'Target': simple_name}
        r_fwi_global = _score(merged, 'risk_score', target_key, sc)
        _fill(row_combined, 'FWI_Global_', r_fwi_global)
        row_combined['AGG_FWI_Global'] = _compute_agg(r_fwi_global, ref_fwi_global)
        
        all_depts = np.sort(merged['departement'].unique())
        for d_id in all_depts:
            m_dept = merged[merged['departement'] == d_id]
            r_fwi_d = _score(m_dept, 'risk_score', target_key, sc)
            ref_fwi_d = load_baseline_metrics(simple_name, 'fwi', d_id)
            _fill(row_combined, f'FWI_{int(d_id)}_', r_fwi_d)
            # Compute AGG per dept using global baseline as reference (or per-dept baseline if available later)
            row_combined[f'AGG_FWI_{int(d_id)}'] = _compute_agg(r_fwi_d, ref_fwi_d)
        
        fwi_results_all.append(row_combined.copy())

        # FWI summer
        df_p = df_pred.copy(deep=True)

        df_p['date'] = df_p['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
        df_p['date'] = pd.to_datetime(df_p['date'])
        df_p = df_p[
            df_p['date'].dt.month.between(6, 9)
        ]
        df_p['num_zone'] = df_p['num_zone'].astype(int)

        gt_temp = gt_df_orig[['date','num_zone', target_key]].copy()
        merged  = pd.merge(df_p, gt_temp, on=['date','num_zone'], how='inner', suffixes=('','_gt'))
        merged = merged[merged['date'].dt.year == int(year_test)]
        if merged.empty:
            print(f"  [{model_name}] empty merge for {year_test} — skipped"); continue

        row_combined = {'Model': model_name, 'Target': simple_name}
        r_fwi_global = _score(merged, 'risk_score', target_key, sc)
        _fill(row_combined, 'FWI_Global_', r_fwi_global)
        row_combined['AGG_FWI_Global'] = _compute_agg(r_fwi_global, ref_fwi_global)
        
        all_depts = np.sort(merged['departement'].unique())
        for d_id in all_depts:
            m_dept = merged[merged['departement'] == d_id]
            r_fwi_d = _score(m_dept, 'risk_score', target_key, sc)
            ref_fwi_d = load_baseline_metrics(simple_name, 'fwi', d_id)
            _fill(row_combined, f'FWI_{int(d_id)}_', r_fwi_d)
            # Compute AGG per dept using global baseline as reference (or per-dept baseline if available later)
            row_combined[f'AGG_FWI_{int(d_id)}'] = _compute_agg(r_fwi_d, ref_fwi_d)
        
        fwi_summer_results_all.append(row_combined.copy())

        # DFE
        dts = merged['date'].dt
        dept_mask = merged['departement'] == 6
        summer_mask = ((dts.month > 6) | ((dts.month == 6) & (dts.day >= 15))) & \
                      ((dts.month < 9) | ((dts.month == 9) & (dts.day <= 25)))

        merged_dfe = merged[summer_mask & dept_mask]
        r_dfe = _score(merged_dfe, 'risk_score', target_key, sc) if not merged_dfe.empty else None
        _fill(row_combined, 'DFE_6_', r_dfe)
        row_combined['AGG_DFE_6'] = _compute_agg(r_dfe, ref_dfe_6)
        
        if r_dfe:
            row_dfe = {'Model': model_name, 'Target': simple_name, 'AGG': row_combined['AGG_DFE_6']}
            row_dfe.update(r_dfe)
            dfe_results_all.append(row_dfe)
        results_list.append(row_combined)
        
    if results_list:
        df_res = pd.DataFrame(results_list).set_index('Model')
        all_target_results[simple_name] = {'scores_lh_plot': df_res}
        agg_cols = [c for c in df_res.columns if 'AGG' in c]
        print(df_res[agg_cols].head())
        
# Save outputs
if dfe_results_all:
    pd.DataFrame(dfe_results_all).to_csv(f'results_dfe_{year_test}_v2.csv', index=False)
    print(f"\n Saved results_dfe_{year_test}_v2.csv ({len(dfe_results_all)} rows)")
if fwi_results_all:
    pd.DataFrame(fwi_results_all).to_csv(f'results_fwi_{year_test}_v2.csv', index=False)
    print(f" Saved results_fwi_{year_test}_v2.csv ({len(fwi_results_all)} rows)")
if fwi_summer_results_all:
    pd.DataFrame(fwi_results_all).to_csv(f'results_fwi_summer_{year_test}_v2.csv', index=False)
    print(f" Saved results_fwi_{year_test}_v2.csv ({len(fwi_results_all)} rows)")
print("\nDone.")
# Out:
# Starting dual scoring (FWI 2023 / DFE 2023 summer) with per-department AGG scores...
#
# ========================================
# Fire (sigma=0.7258)
# ========================================
#                                                     AGG_FWI_Global  AGG_FWI_1  \
# Model
# GRU_search_full_10_0_all_one_regression_pdegpd            0.046470   0.260417
# GRU_search_full_10_0_all_one_classification_flw...        0.313572   0.604172
# GRU_search_full_10_0_all_one_classification_flwk          0.482095   0.673638
# GRU_search_full_10_0_all_one_classification_bce...       -0.299838   0.239972
# GRU_search_full_10_0_all_one_classification_fl           -0.267348  -0.276500
#
#                                                     AGG_FWI_6  AGG_FWI_25  \
# Model
# GRU_search_full_10_0_all_one_regression_pdegpd      -0.082538    0.223171
# GRU_search_full_10_0_all_one_classification_flw...   0.101167    0.300981
# GRU_search_full_10_0_all_one_classification_flwk    -0.191836    0.486832
# GRU_search_full_10_0_all_one_classification_bce...  -0.138579    0.057046
# GRU_search_full_10_0_all_one_classification_fl       0.090148   -0.433119
#
#                                                     AGG_DFE_6
# Model
# GRU_search_full_10_0_all_one_regression_pdegpd      -0.133304
# GRU_search_full_10_0_all_one_classification_flw...  -0.027639
# GRU_search_full_10_0_all_one_classification_flwk    -0.487032
# GRU_search_full_10_0_all_one_classification_bce...  -0.375351
# GRU_search_full_10_0_all_one_classification_fl      -0.031292
#
# ========================================
# Ressource (sigma=1.3098)
# ========================================
#                                                     AGG_FWI_Global  AGG_FWI_1  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...        0.265735  -0.033363
# GRU_search_full_10_0_all_one_classification_flwk          0.402098  -0.193592
# GRU_search_full_10_0_all_one_classification_wei...        0.049614   0.425583
# GRU_search_full_10_0_all_one_classification_wkloss        0.332749   0.425774
# GRU_search_full_10_0_all_one_classification_bce...        0.029450  -0.142867
#
#                                                     AGG_FWI_6  AGG_FWI_25  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...  -0.011562   -0.201384
# GRU_search_full_10_0_all_one_classification_flwk     0.288682   -0.156939
# GRU_search_full_10_0_all_one_classification_wei...  -0.072503    0.606969
# GRU_search_full_10_0_all_one_classification_wkloss   0.629987    0.678699
# GRU_search_full_10_0_all_one_classification_bce...   0.638639   -0.033685
#
#                                                     AGG_DFE_6
# Model
# GRU_search_full_10_0_all_one_classification_flw...  -0.584827
# GRU_search_full_10_0_all_one_classification_flwk    -0.474860
# GRU_search_full_10_0_all_one_classification_wei...  -0.627113
# GRU_search_full_10_0_all_one_classification_wkloss  -0.148626
# GRU_search_full_10_0_all_one_classification_bce...   0.349280
#
# ========================================
# Time (sigma=201.6074)
# ========================================
#                                                     AGG_FWI_Global  AGG_FWI_1  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...       -0.124914        0.0
# GRU_search_full_10_0_all_one_classification_flwk         -0.137535        0.0
# GRU_search_full_10_0_all_one_classification_wei...       -0.104737        0.0
# GRU_search_full_10_0_all_one_classification_wkloss        0.114528        0.0
# GRU_search_full_10_0_all_one_classification_bce...       -0.086132        0.0
#
#                                                     AGG_FWI_6  AGG_FWI_25  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...   0.289157   -0.126161
# GRU_search_full_10_0_all_one_classification_flwk     0.264384    0.364946
# GRU_search_full_10_0_all_one_classification_wei...   0.236615    0.094934
# GRU_search_full_10_0_all_one_classification_wkloss  -0.339156   -0.192917
# GRU_search_full_10_0_all_one_classification_bce...   0.280982   -0.133319
#
#                                                     AGG_DFE_6
# Model
# GRU_search_full_10_0_all_one_classification_flw...   0.000127
# GRU_search_full_10_0_all_one_classification_flwk    -0.422729
# GRU_search_full_10_0_all_one_classification_wei...  -0.065743
# GRU_search_full_10_0_all_one_classification_wkloss  -0.454119
# GRU_search_full_10_0_all_one_classification_bce...  -0.195400
#
#  Saved results_dfe_2023_v2.csv (23 rows)
#  Saved results_fwi_2023_v2.csv (23 rows)
#  Saved results_fwi_2023_v2.csv (23 rows)
#
# Done.

# %%
# Save outputs
def save_comparison_csv(results_all, name, path_baseline):
    if not results_all:
        return
    import pandas as pd
    import os
    df = pd.DataFrame(results_all)
    
    # Mapping des noms de targets techniques vers les noms demandés
    target_mapping = {
        'nbsinister': 'Fire',
        'ressource': 'Ressource',
        'burnedareaRoot': 'BA',
        'burnedarea': 'BA',
        'timeintervention': 'Time'
    }
    
    def map_target(t):
        if not t or not isinstance(t, str): return t
        for key, val in target_mapping.items():
            if key in t.lower():
                return val
        return t
        
    if 'Target' in df.columns:
        df['Target'] = df['Target'].apply(map_target)
    
    print(df.columns)
    # Identification des colonnes AGG
    score_cols = ['k1', 'k2', 'k3', 'k4', 'recall', 'min_class', 'AGG']
    agg_cols = []
    for s in score_cols:
        agg_cols += [col for col in df.columns if s in col]
    id_cols = ['Model', 'Target']
    
    # On garde les colonnes d'identification + les colonnes AGG
    available_cols = [c for c in id_cols + agg_cols if c in df.columns]
    df_agg = df[available_cols]
    
    # Transformation en format long pour avoir une ligne par département
    df_long = df_agg.melt(id_vars=['Model', 'Target'], var_name='Metric', value_name='Score')
    
    # Extraction du département et du système depuis le nom de la métrique (ex: AGG_FWI_6)
    def parse_metric(m):
        parts = m.split('_')
        if len(parts) >= 3:
            return parts[1], parts[2]
        return 'Unknown', 'Unknown'
    
    if not df_long.empty:
        extra_cols = df_long['Metric'].apply(lambda x: pd.Series(parse_metric(x)))
        extra_cols.columns = ['System', 'Department']
        df_long = pd.concat([df_long, extra_cols], axis=1)
    
    # On sauvegarde
    os.makedirs(path_baseline, exist_ok=True)
    csv_path = os.path.join(path_baseline, f'comparison_{name}_scores.csv')
    df_long.to_csv(csv_path, index=False)
    print(f"Table de comparaison {name.upper()} sauvegardée dans : {csv_path}")

# %%
# --- Per-Target comparison tables: Models vs FWI Baseline (2023, dept from MODE) ---
import pandas as pd
import numpy as np

# Département extrait depuis MODE ('06' -> 6)

dept = [1, 6, 25, "Global"]

all_dept_tables = []
    
for d in dept:
    if d == 'Global':
        BASELINE_DATASET_KEY = year_test
    else:
        BASELINE_DATASET_KEY = f"{year_test}_{d}"

    def load_fwi_baseline(target_name):
        """
        Load FWI baseline for target_name from path_baseline/fwi_scores_{target_name}.csv.
        Uses row Dataset == '2023_{DEPT}', fallback to 'Global'.
        Returns dict with score_k1..4, recall, score_min_class or None.
        """
        fname = path_baseline / f"fwi_scores_{target_name}.csv"
        try:
            bdf = pd.read_csv(fname)
        except FileNotFoundError:
            print(f"  baseline file not found: {fname}")
            return None
        row = bdf[bdf['Dataset'] == BASELINE_DATASET_KEY]
        if row.empty:
            print('ERRROROROR')
            raise ValueError
            row = bdf[bdf['Dataset'] == 'Global']
            if not row.empty:
                print(f"  [{target_name}] no row for {BASELINE_DATASET_KEY!r}, using 'Global'")
        if row.empty:
            print(f"  [{target_name}] no baseline row found (tried {BASELINE_DATASET_KEY!r} and 'Global')")
            return None

        data = row.iloc[0]
        return {
            'score_k1':       float(data.get('k1', np.nan)),
            'score_k2':       float(data.get('k2', np.nan)),
            'score_k3':       float(data.get('k3', np.nan)),
            'score_k4':       float(data.get('k4', np.nan)),
            'recall':         float(data.get('recall', np.nan)),
            'score_min_class': float(data.get('score_min_class', np.nan)),
        }

    def get_val(row, *candidates):
        for c in candidates:
            if c in row.index and pd.notna(row[c]):
                return float(row[c])
        return np.nan

    DISPLAY_COLS = [
        ('score_k1',        'k1'),
        ('score_k2',        'k2'),
        ('score_k3',        'k3'),
        ('score_k4',        'k4'),
        ('recall',          'recall'),
        ('score_min_class', 'min_class'),
        ('agg',             'AGG'),
    ]

    for target in ['Fire', 'Ressource', 'Time']:
        
        if d == 1 and target == 'Time':
            continue

        if target not in all_target_results:
            print(f"[{target}] not in all_target_results — skipping.")
            continue

        scores_lh = all_target_results[target].get('scores_lh_plot', pd.DataFrame())
        if scores_lh.empty:
            print(f"[{target}] scores_lh_plot empty — skipping.")
            continue

        ref = load_fwi_baseline(target)
        rows = []

        # --- Baseline row ---
        if ref:
            base_row = {'Model': f'Baseline FWI ({BASELINE_DATASET_KEY})'}
            for sk, label in DISPLAY_COLS:
                if sk == 'agg':
                    base_row[label] = np.nan
                else:
                    base_row[label] = ref.get(sk, np.nan)
            rows.append(base_row)
        else:
            print(f"  [{target}] baseline not loaded.")

        # --- Model rows ---
        for model_name, row in scores_lh.iterrows():
            model_row = {'Model': model_name}
            for sk, label in DISPLAY_COLS:
                if sk == 'agg':
                    val = get_val(row, f'AGG_FWI_{d}')
                elif sk == 'recall':
                    val = get_val(row, f'FWI_{d}_RECALL', 'RECALL')
                elif sk == 'score_min_class':
                    val = get_val(row, f'FWI_{d}_SCORE_MIN_CLASS', 'SCORE_MIN_CLASS')
                else:
                    k = sk[-1]
                    val = get_val(row,
                        f'FWI_{d}_SCORE_k{k}',
                        f'SCORE_k{k}',
                    )
                model_row[label] = val
            rows.append(model_row)

        df_table = pd.DataFrame(rows).set_index('Model')
        df_table['Target'] = target

        if d != 'Global':
            all_dept_tables.append(df_table)

        print(f"\n{'═'*65}")
        print(f"  {target}  —  baseline: {BASELINE_DATASET_KEY}")
        print(f"{'═'*65}")
        print(df_table.to_markdown(floatfmt=".4f"))
        print()

# --- Print Average Table ---
if all_dept_tables:
    df_avg = pd.concat(all_dept_tables)
    tars = df_avg['Target'].unique()
    for target in tars:
        df_avg_tar = df_avg[df_avg['Target'] == target]
        df_avg_tar.drop('Target', inplace=True, axis=1)
        df_avg_tar = df_avg_tar.groupby('Model').mean()
        
        # Sort to keep the baseline at the top if it's there
        baseline_index = [i for i in df_avg_tar.index if 'Baseline' in i]
        other_index = [i for i in df_avg_tar.index if 'Baseline' not in i]
        df_avg_tar = df_avg_tar.reindex(baseline_index + other_index)
        
        print(f"\n{'═'*65}")
        print(f"  {target}  —  Average (Depts: 1, 6, 25)")
        print(f"{'═'*65}")
        print(df_avg_tar.to_markdown(floatfmt=".4f"))
        print()
        
save_comparison_csv(fwi_results_all, 'fwi', path_baseline)
print("\nDone.")
# Out:
# ═════════════════════════════════════════════════════════════════
#   Fire  —  baseline: 2023_1
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG | Target   |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|:---------|
# | Baseline FWI (2023_1)                                                | -0.1409 | -0.1292 | -0.0376 |  0.1219 |   0.7834 |      1.0000 | nan      | Fire     |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       |  0.2749 |  0.3995 |  0.0000 |  0.0000 |   0.7607 |      1.0000 |   0.2604 | Fire     |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.0725 |  0.1158 |  0.1515 |  0.2424 |   0.8221 |      1.0000 |   0.6042 | Fire     |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.2037 |  0.2516 |  0.3160 |  0.4133 |   0.8466 |      1.0000 |   0.6736 | Fire     |
# | GRU_search_full_10_0_all_one_classification_bceloss                  |  0.0349 |  0.0000 |  0.0267 |  0.0285 |   0.7117 |      1.0000 |   0.2400 | Fire     |
# | GRU_search_full_10_0_all_one_classification_fl                       | -0.1669 | -0.1317 | -0.1289 | -0.0795 |   0.9387 |      1.0000 |  -0.2765 | Fire     |
# | GRU_search_full_10_0_all_one_regression_cll                          |  0.1243 |  0.1361 |  0.1493 |  0.0000 |   0.6871 |      1.0000 |   0.3320 | Fire     |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} | -0.0046 |  0.0454 |  0.0488 |  0.0496 |   0.9509 |      1.0000 |   0.3332 | Fire     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Ressource  —  baseline: 2023_1
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG | Target    |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|:----------|
# | Baseline FWI (2023_1)                                                | -0.1029 | -0.1011 | -0.0497 |  0.0528 |   0.7970 |      1.0000 | nan      | Ressource |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -0.2206 | -0.0468 |  0.0196 | -0.0249 |   0.9387 |      1.0000 |  -0.0334 | Ressource |
# | GRU_search_full_10_0_all_one_classification_flwk                     | -0.1578 | -0.1109 | -0.0854 |  0.0205 |   0.8589 |      1.0000 |  -0.1936 | Ressource |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     |  0.1712 |  0.0000 |  0.0586 |  0.0758 |   0.6196 |      1.0000 |   0.4256 | Ressource |
# | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.0141 |  0.0472 |  0.0510 |  0.0582 |   0.8160 |      1.0000 |   0.4258 | Ressource |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -0.9081 |  0.0000 | -0.0300 | -0.1643 |   0.9264 |      1.0000 |  -0.1429 | Ressource |
# | GRU_search_full_10_0_all_one_classification_fl                       | -0.7579 | -0.3396 |  0.0573 |  0.0058 |   0.9080 |      1.0000 |  -0.2488 | Ressource |
# | GRU_search_full_10_0_all_one_regression_cll                          |  0.1665 |  0.2288 |  0.2795 |  0.0000 |   0.6442 |      1.0000 |   0.3851 | Ressource |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0065 |  0.0496 |  0.0738 |  0.0539 |   0.8282 |      1.0000 |   0.4307 | Ressource |
#
#
# ═════════════════════════════════════════════════════════════════
#   Fire  —  baseline: 2023_6
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |     k3 |     k4 |   recall |   min_class |      AGG | Target   |
# |:---------------------------------------------------------------------|--------:|--------:|-------:|-------:|---------:|------------:|---------:|:---------|
# | Baseline FWI (2023_6)                                                | -0.0241 |  0.0014 | 0.0316 | 0.0995 |   0.7990 |      1.0000 | nan      | Fire     |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       |  0.0905 |  0.0000 | 0.0000 | 0.0000 |   0.6100 |      1.0000 |  -0.0825 | Fire     |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.0996 |  0.1152 | 0.0000 | 0.0000 |   0.8100 |      1.0000 |   0.1012 | Fire     |
# | GRU_search_full_10_0_all_one_classification_flwk                     | -0.0068 | -0.0060 | 0.0000 | 0.0000 |   0.6500 |      1.0000 |  -0.1918 | Fire     |
# | GRU_search_full_10_0_all_one_classification_bceloss                  |  0.0513 |  0.0000 | 0.0000 | 0.0000 |   0.4700 |      1.0000 |  -0.1386 | Fire     |
# | GRU_search_full_10_0_all_one_classification_fl                       |  0.0333 |  0.2180 | 0.0000 | 0.0000 |   0.8900 |      1.0000 |   0.0901 | Fire     |
# | GRU_search_full_10_0_all_one_regression_cll                          | -0.0124 |  0.0369 | 0.0000 | 0.0000 |   0.5500 |      1.0000 |  -0.1516 | Fire     |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0037 |  0.0592 | 0.0725 | 0.0597 |   0.9150 |      1.0000 |   0.1577 | Fire     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Ressource  —  baseline: 2023_6
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |     k4 |   recall |   min_class |      AGG | Target    |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|-------:|---------:|------------:|---------:|:----------|
# | Baseline FWI (2023_6)                                                | -0.3866 | -0.1942 | -0.0976 | 0.2956 |   0.7997 |      1.0000 | nan      | Ressource |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -0.4732 | -0.1908 |  0.0537 | 0.0094 |   0.7789 |      1.0000 |  -0.0116 | Ressource |
# | GRU_search_full_10_0_all_one_classification_flwk                     | -0.0313 |  0.0734 |  0.0892 | 0.0420 |   0.6935 |      1.0000 |   0.2887 | Ressource |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | -0.7685 |  0.0000 |  0.0000 | 0.0000 |   0.4322 |      1.0000 |  -0.0725 | Ressource |
# | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.0908 |  0.1039 |  0.3253 | 0.8210 |   0.8643 |      1.0000 |   0.6300 | Ressource |
# | GRU_search_full_10_0_all_one_classification_bceloss                  |  0.5223 |  0.0000 |  0.8595 | 0.8079 |   0.9196 |      1.0000 |   0.6386 | Ressource |
# | GRU_search_full_10_0_all_one_classification_fl                       |  0.4122 |  0.0000 |  0.0000 | 0.0000 |   0.8241 |      1.0000 |   0.2917 | Ressource |
# | GRU_search_full_10_0_all_one_regression_cll                          | -0.3069 |  0.2055 |  0.0000 | 0.0000 |   0.2814 |      1.0000 |   0.0984 | Ressource |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.2336 |  0.3755 |  0.0000 | 0.0000 |   0.5377 |      1.0000 |   0.2650 | Ressource |
#
#
# ═════════════════════════════════════════════════════════════════
#   Time  —  baseline: 2023_6
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |     k4 |   recall |   min_class |      AGG | Target   |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|-------:|---------:|------------:|---------:|:---------|
# | Baseline FWI (2023_6)                                                | -1.2935 | -0.2647 | -0.0514 | 0.3014 |   0.7997 |      1.0000 | nan      | Time     |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.3479 |  0.0000 |  0.0329 | 0.0962 |   0.8191 |      1.0000 |   0.2892 | Time     |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.0532 |  0.0000 |  0.0498 | 0.0505 |   0.7688 |      1.0000 |   0.2644 | Time     |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     |  0.4477 |  0.0000 | -0.0183 | 0.0851 |   0.8643 |      1.0000 |   0.2366 | Time     |
# | GRU_search_full_10_0_all_one_classification_wkloss                   | -0.9249 | -0.7307 | -0.4613 | 0.0877 |   0.9950 |      1.0000 |  -0.3392 | Time     |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -0.0163 |  0.0000 |  0.0655 | 0.0513 |   0.8191 |      1.0000 |   0.2810 | Time     |
# | GRU_search_full_10_0_all_one_classification_fl                       |  0.2470 |  0.0000 |  0.0895 | 0.1211 |   0.7688 |      1.0000 |   0.3176 | Time     |
# | GRU_search_full_10_0_all_one_regression_cll                          | -1.2774 | -0.5502 | -0.6616 | 0.0000 |   0.8744 |      1.0000 |  -0.4081 | Time     |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} | -0.0338 |  0.1449 |  0.3046 | 0.0000 |   0.8794 |      1.0000 |   0.3333 | Time     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Fire  —  baseline: 2023_25
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |     k3 |      k4 |   recall |   min_class |      AGG | Target   |
# |:---------------------------------------------------------------------|--------:|--------:|-------:|--------:|---------:|------------:|---------:|:---------|
# | Baseline FWI (2023_25)                                               |  0.0098 |  0.0655 | 0.0735 |  0.0000 |   0.6919 |      1.0000 | nan      | Fire     |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       |  0.1628 |  0.2883 | 0.0000 |  0.0000 |   0.7456 |      1.0000 |   0.2232 | Fire     |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.0646 |  0.0921 | 0.0957 |  0.0894 |   0.7719 |      1.0000 |   0.3010 | Fire     |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.0909 |  0.0970 | 0.1891 |  0.3665 |   0.7807 |      1.0000 |   0.4868 | Fire     |
# | GRU_search_full_10_0_all_one_classification_bceloss                  |  0.1047 |  0.0000 | 0.0427 |  0.0567 |   0.6667 |      1.0000 |   0.0570 | Fire     |
# | GRU_search_full_10_0_all_one_classification_fl                       | -0.1756 | -0.0462 | 0.0142 | -0.0529 |   0.8158 |      1.0000 |  -0.4331 | Fire     |
# | GRU_search_full_10_0_all_one_regression_cll                          |  0.0648 |  0.0778 | 0.1052 |  0.0000 |   0.6491 |      1.0000 |   0.1447 | Fire     |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0891 |  0.1206 | 0.1591 |  0.2144 |   0.9035 |      1.0000 |   0.5209 | Fire     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Ressource  —  baseline: 2023_25
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG | Target    |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|:----------|
# | Baseline FWI (2023_25)                                               |  0.0000 |  0.0000 |  0.0000 |  0.0000 |   0.0000 |      1.0000 | nan      | Ressource |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -1.4989 | -0.6430 |  0.0773 | -0.1281 |   0.8725 |      1.0000 |  -0.2014 | Ressource |
# | GRU_search_full_10_0_all_one_classification_flwk                     | -0.3269 | -0.2776 | -0.1441 |  0.1752 |   0.7255 |      1.0000 |  -0.1569 | Ressource |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     |  0.0782 |  0.0000 |  0.3103 |  0.2748 |   0.6961 |      1.0000 |   0.6070 | Ressource |
# | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.0157 |  0.1845 |  0.2439 |  0.2302 |   0.6569 |      1.0000 |   0.6787 | Ressource |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -2.3412 |  0.0000 |  0.0847 | -0.1429 |   0.9902 |      1.0000 |  -0.0337 | Ressource |
# | GRU_search_full_10_0_all_one_classification_fl                       | -2.0244 |  0.0000 |  0.1873 |  0.0554 |   0.8725 |      1.0000 |   0.2429 | Ressource |
# | GRU_search_full_10_0_all_one_regression_cll                          |  0.5584 |  0.7377 |  0.7109 |  0.0000 |   0.5588 |      1.0000 |   0.6667 | Ressource |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.4012 |  0.4690 |  0.4701 |  0.4704 |   0.7941 |      1.0000 |   0.8331 | Ressource |
#
#
# ═════════════════════════════════════════════════════════════════
#   Time  —  baseline: 2023_25
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG | Target   |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|:---------|
# | Baseline FWI (2023_25)                                               |  0.0000 |  0.0000 |  0.0000 |  0.0000 |   0.0000 |      1.0000 | nan      | Time     |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -0.5253 |  0.0000 |  0.0014 | -0.1023 |   0.8641 |      1.0000 |  -0.1262 | Time     |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.0396 |  0.0000 |  0.0436 |  0.0428 |   0.7961 |      1.0000 |   0.3649 | Time     |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | -0.3531 |  0.0000 |  0.0465 |  0.0135 |   0.7961 |      1.0000 |   0.0949 | Time     |
# | GRU_search_full_10_0_all_one_classification_wkloss                   | -0.3073 | -0.1850 | -0.1232 |  0.0747 |   0.8932 |      1.0000 |  -0.1929 | Time     |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -1.0348 |  0.0000 |  0.0141 | -0.1741 |   0.8544 |      1.0000 |  -0.1333 | Time     |
# | GRU_search_full_10_0_all_one_classification_fl                       |  0.0435 |  0.0000 |  0.0103 |  0.0170 |   0.8447 |      1.0000 |   0.2800 | Time     |
# | GRU_search_full_10_0_all_one_regression_cll                          | -0.5597 | -0.4610 | -0.3089 |  0.0000 |   0.9515 |      1.0000 |  -0.3326 | Time     |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0087 |  0.0394 |  0.0589 |  0.0000 |   0.9709 |      1.0000 |   0.3317 | Time     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Fire  —  baseline: 2023
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |     k1 |     k2 |     k3 |     k4 |   recall |   min_class |      AGG | Target   |
# |:---------------------------------------------------------------------|-------:|-------:|-------:|-------:|---------:|------------:|---------:|:---------|
# | Baseline FWI (2023)                                                  | 0.1363 | 0.1401 | 0.1578 | 0.1727 |   0.7555 |      1.0000 | nan      | Fire     |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       | 0.3351 | 0.4870 | 0.0000 | 0.0000 |   0.6939 |      1.0000 |   0.0465 | Fire     |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | 0.1742 | 0.2023 | 0.2305 | 0.3218 |   0.8050 |      1.0000 |   0.3136 | Fire     |
# | GRU_search_full_10_0_all_one_classification_flwk                     | 0.2250 | 0.2608 | 0.3235 | 0.3902 |   0.7484 |      1.0000 |   0.4821 | Fire     |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | 0.1779 | 0.0000 | 0.0444 | 0.0745 |   0.5996 |      1.0000 |  -0.2998 | Fire     |
# | GRU_search_full_10_0_all_one_classification_fl                       | 0.0487 | 0.0854 | 0.0978 | 0.0830 |   0.8889 |      1.0000 |  -0.2673 | Fire     |
# | GRU_search_full_10_0_all_one_regression_cll                          | 0.1551 | 0.1719 | 0.2085 | 0.0000 |   0.6205 |      1.0000 |  -0.0446 | Fire     |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} | 0.1185 | 0.1647 | 0.1885 | 0.1677 |   0.9245 |      1.0000 |   0.0712 | Fire     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Ressource  —  baseline: 2023
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |     k1 |     k2 |     k3 |     k4 |   recall |   min_class |      AGG | Target    |
# |:---------------------------------------------------------------------|-------:|-------:|-------:|-------:|---------:|------------:|---------:|:----------|
# | Baseline FWI (2023)                                                  | 0.0859 | 0.1091 | 0.1534 | 0.2744 |   0.7989 |      1.0000 | nan      | Ressource |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | 0.2466 | 0.1823 | 0.2004 | 0.1949 |   0.8556 |      1.0000 |   0.2657 | Ressource |
# | GRU_search_full_10_0_all_one_classification_flwk                     | 0.2617 | 0.2667 | 0.2692 | 0.2711 |   0.7586 |      1.0000 |   0.4021 | Ressource |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | 0.3764 | 0.0000 | 0.2274 | 0.2502 |   0.5560 |      1.0000 |   0.0496 | Ressource |
# | GRU_search_full_10_0_all_one_classification_wkloss                   | 0.1832 | 0.2262 | 0.2575 | 0.2361 |   0.8017 |      1.0000 |   0.3327 | Ressource |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | 0.4035 | 0.0000 | 0.1601 | 0.1973 |   0.9375 |      1.0000 |   0.0295 | Ressource |
# | GRU_search_full_10_0_all_one_classification_fl                       | 0.3504 | 0.2519 | 0.2448 | 0.2604 |   0.8642 |      1.0000 |   0.4031 | Ressource |
# | GRU_search_full_10_0_all_one_regression_cll                          | 0.5238 | 0.6059 | 0.6693 | 0.0000 |   0.4698 |      1.0000 |   0.3076 | Ressource |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} | 0.1786 | 0.2413 | 0.2776 | 0.2547 |   0.6961 |      1.0000 |   0.3394 | Ressource |
#
#
# ═════════════════════════════════════════════════════════════════
#   Time  —  baseline: 2023
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |     k2 |     k3 |     k4 |   recall |   min_class |      AGG | Target   |
# |:---------------------------------------------------------------------|--------:|-------:|-------:|-------:|---------:|------------:|---------:|:---------|
# | Baseline FWI (2023)                                                  | -0.1142 | 0.0946 | 0.0997 | 0.1496 |   0.7997 |      1.0000 | nan      | Time     |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.1998 | 0.0000 | 0.0368 | 0.0695 |   0.8344 |      1.0000 |  -0.1249 | Time     |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.0704 | 0.0000 | 0.0533 | 0.0568 |   0.7781 |      1.0000 |  -0.1375 | Time     |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     |  0.1741 | 0.0000 | 0.0493 | 0.0744 |   0.8411 |      1.0000 |  -0.1047 | Time     |
# | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.0678 | 0.0800 | 0.0942 | 0.1143 |   0.9603 |      1.0000 |   0.1145 | Time     |
# | GRU_search_full_10_0_all_one_classification_bceloss                  |  0.0444 | 0.0000 | 0.0775 | 0.0709 |   0.8311 |      1.0000 |  -0.0861 | Time     |
# | GRU_search_full_10_0_all_one_classification_fl                       |  0.1272 | 0.0000 | 0.0544 | 0.0690 |   0.7947 |      1.0000 |  -0.1149 | Time     |
# | GRU_search_full_10_0_all_one_regression_cll                          |  0.0908 | 0.1454 | 0.1682 | 0.0000 |   0.9007 |      1.0000 |   0.2289 | Time     |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0652 | 0.0935 | 0.0863 | 0.0728 |   0.9106 |      1.0000 |   0.0729 | Time     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Fire  —  Average (Depts: 1, 6, 25)
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|
# | Baseline FWI (2023_1)                                                | -0.1409 | -0.1292 | -0.0376 |  0.1219 |   0.7834 |      1.0000 | nan      |
# | Baseline FWI (2023_25)                                               |  0.0098 |  0.0655 |  0.0735 |  0.0000 |   0.6919 |      1.0000 | nan      |
# | Baseline FWI (2023_6)                                                | -0.0241 |  0.0014 |  0.0316 |  0.0995 |   0.7990 |      1.0000 | nan      |
# | GRU_search_full_10_0_all_one_classification_bceloss                  |  0.0636 |  0.0000 |  0.0231 |  0.0284 |   0.6161 |      1.0000 |   0.0528 |
# | GRU_search_full_10_0_all_one_classification_fl                       | -0.1031 |  0.0134 | -0.0383 | -0.0442 |   0.8815 |      1.0000 |  -0.2065 |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.0960 |  0.1142 |  0.1684 |  0.2599 |   0.7591 |      1.0000 |   0.3229 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.0789 |  0.1077 |  0.0824 |  0.1106 |   0.8013 |      1.0000 |   0.3354 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0294 |  0.0751 |  0.0935 |  0.1079 |   0.9231 |      1.0000 |   0.3372 |
# | GRU_search_full_10_0_all_one_regression_cll                          |  0.0589 |  0.0836 |  0.0848 |  0.0000 |   0.6287 |      1.0000 |   0.1083 |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       |  0.1761 |  0.2293 |  0.0000 |  0.0000 |   0.7055 |      1.0000 |   0.1337 |
#
#
# ═════════════════════════════════════════════════════════════════
#   Ressource  —  Average (Depts: 1, 6, 25)
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|
# | Baseline FWI (2023_1)                                                | -0.1029 | -0.1011 | -0.0497 |  0.0528 |   0.7970 |      1.0000 | nan      |
# | Baseline FWI (2023_25)                                               |  0.0000 |  0.0000 |  0.0000 |  0.0000 |   0.0000 |      1.0000 | nan      |
# | Baseline FWI (2023_6)                                                | -0.3866 | -0.1942 | -0.0976 |  0.2956 |   0.7997 |      1.0000 | nan      |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -0.9090 |  0.0000 |  0.3047 |  0.1669 |   0.9454 |      1.0000 |   0.1540 |
# | GRU_search_full_10_0_all_one_classification_fl                       | -0.7900 | -0.1132 |  0.0815 |  0.0204 |   0.8682 |      1.0000 |   0.0953 |
# | GRU_search_full_10_0_all_one_classification_flwk                     | -0.1720 | -0.1051 | -0.0468 |  0.0793 |   0.7593 |      1.0000 |  -0.0206 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -0.7309 | -0.2935 |  0.0502 | -0.0479 |   0.8634 |      1.0000 |  -0.0821 |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | -0.1730 |  0.0000 |  0.1230 |  0.1169 |   0.5826 |      1.0000 |   0.3200 |
# | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.0402 |  0.1119 |  0.2067 |  0.3698 |   0.7790 |      1.0000 |   0.5782 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.2138 |  0.2980 |  0.1813 |  0.1748 |   0.7200 |      1.0000 |   0.5096 |
# | GRU_search_full_10_0_all_one_regression_cll                          |  0.1393 |  0.3907 |  0.3301 |  0.0000 |   0.4948 |      1.0000 |   0.3834 |
#
#
# ═════════════════════════════════════════════════════════════════
#   Time  —  Average (Depts: 1, 6, 25)
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|
# | Baseline FWI (2023_25)                                               |  0.0000 |  0.0000 |  0.0000 |  0.0000 |   0.0000 |      1.0000 | nan      |
# | Baseline FWI (2023_6)                                                | -1.2935 | -0.2647 | -0.0514 |  0.3014 |   0.7997 |      1.0000 | nan      |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -0.5255 |  0.0000 |  0.0398 | -0.0614 |   0.8367 |      1.0000 |   0.0738 |
# | GRU_search_full_10_0_all_one_classification_fl                       |  0.1453 |  0.0000 |  0.0499 |  0.0690 |   0.8068 |      1.0000 |   0.2988 |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.0464 |  0.0000 |  0.0467 |  0.0466 |   0.7825 |      1.0000 |   0.3147 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -0.0887 |  0.0000 |  0.0171 | -0.0030 |   0.8416 |      1.0000 |   0.0815 |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     |  0.0473 |  0.0000 |  0.0141 |  0.0493 |   0.8302 |      1.0000 |   0.1658 |
# | GRU_search_full_10_0_all_one_classification_wkloss                   | -0.6161 | -0.4578 | -0.2922 |  0.0812 |   0.9441 |      1.0000 |  -0.2660 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} | -0.0126 |  0.0921 |  0.1818 |  0.0000 |   0.9251 |      1.0000 |   0.3325 |
# | GRU_search_full_10_0_all_one_regression_cll                          | -0.9185 | -0.5056 | -0.4852 |  0.0000 |   0.9129 |      1.0000 |  -0.3704 |
#
# Index(['Model', 'Target', 'FWI_Global_SCORE_k1', 'FWI_Global_SCORE_k2',
#        'FWI_Global_SCORE_k3', 'FWI_Global_SCORE_k4', 'FWI_Global_SCORE_HIGH',
#        'FWI_Global_SCORE_LOW', 'FWI_Global_SCORE_MIN_CLASS',
#        'FWI_Global_RECALL', 'AGG_FWI_Global', 'FWI_1_SCORE_k1',
#        'FWI_1_SCORE_k2', 'FWI_1_SCORE_k3', 'FWI_1_SCORE_k4',
#        'FWI_1_SCORE_HIGH', 'FWI_1_SCORE_LOW', 'FWI_1_SCORE_MIN_CLASS',
#        'FWI_1_RECALL', 'AGG_FWI_1', 'FWI_6_SCORE_k1', 'FWI_6_SCORE_k2',
#        'FWI_6_SCORE_k3', 'FWI_6_SCORE_k4', 'FWI_6_SCORE_HIGH',
#        'FWI_6_SCORE_LOW', 'FWI_6_SCORE_MIN_CLASS', 'FWI_6_RECALL', 'AGG_FWI_6',
#        'FWI_25_SCORE_k1', 'FWI_25_SCORE_k2', 'FWI_25_SCORE_k3',
#        'FWI_25_SCORE_k4', 'FWI_25_SCORE_HIGH', 'FWI_25_SCORE_LOW',
#        'FWI_25_SCORE_MIN_CLASS', 'FWI_25_RECALL', 'AGG_FWI_25'],
#       dtype='object')
# Table de comparaison FWI sauvegardée dans : firemen2/comparison_fwi_scores.csv
#
# Done.
# /tmp/ipykernel_1226066/3801028281.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg_tar.drop('Target', inplace=True, axis=1)
# /tmp/ipykernel_1226066/3801028281.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg_tar.drop('Target', inplace=True, axis=1)
# /tmp/ipykernel_1226066/3801028281.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg_tar.drop('Target', inplace=True, axis=1)

# %%
df_res
# Out:
#                                                    Target  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...   Time
# GRU_search_full_10_0_all_one_classification_flwk     Time
# GRU_search_full_10_0_all_one_classification_wei...   Time
# GRU_search_full_10_0_all_one_classification_wkloss   Time
# GRU_search_full_10_0_all_one_classification_bce...   Time
# GRU_search_full_10_0_all_one_classification_fl       Time
# GRU_search_full_10_0_all_one_regression_cll          Time
# GRU_search_full_10_0_all_one_regression_ccllt-i...   Time
#
#                                                     FWI_Global_SCORE_k1  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...             0.199790
# GRU_search_full_10_0_all_one_classification_flwk               0.070417
# GRU_search_full_10_0_all_one_classification_wei...             0.174104
# GRU_search_full_10_0_all_one_classification_wkloss             0.067778
# GRU_search_full_10_0_all_one_classification_bce...             0.044408
# GRU_search_full_10_0_all_one_classification_fl                 0.127211
# GRU_search_full_10_0_all_one_regression_cll                    0.090833
# GRU_search_full_10_0_all_one_regression_ccllt-i...             0.065241
#
#                                                     FWI_Global_SCORE_k2  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...             0.000000
# GRU_search_full_10_0_all_one_classification_flwk               0.000000
# GRU_search_full_10_0_all_one_classification_wei...             0.000000
# GRU_search_full_10_0_all_one_classification_wkloss             0.080032
# GRU_search_full_10_0_all_one_classification_bce...             0.000000
# GRU_search_full_10_0_all_one_classification_fl                 0.000000
# GRU_search_full_10_0_all_one_regression_cll                    0.145438
# GRU_search_full_10_0_all_one_regression_ccllt-i...             0.093480
#
#                                                     FWI_Global_SCORE_k3  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...             0.036787
# GRU_search_full_10_0_all_one_classification_flwk               0.053349
# GRU_search_full_10_0_all_one_classification_wei...             0.049321
# GRU_search_full_10_0_all_one_classification_wkloss             0.094156
# GRU_search_full_10_0_all_one_classification_bce...             0.077508
# GRU_search_full_10_0_all_one_classification_fl                 0.054400
# GRU_search_full_10_0_all_one_regression_cll                    0.168165
# GRU_search_full_10_0_all_one_regression_ccllt-i...             0.086260
#
#                                                     FWI_Global_SCORE_k4  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...             0.069547
# GRU_search_full_10_0_all_one_classification_flwk               0.056779
# GRU_search_full_10_0_all_one_classification_wei...             0.074399
# GRU_search_full_10_0_all_one_classification_wkloss             0.114328
# GRU_search_full_10_0_all_one_classification_bce...             0.070856
# GRU_search_full_10_0_all_one_classification_fl                 0.069033
# GRU_search_full_10_0_all_one_regression_cll                    0.000000
# GRU_search_full_10_0_all_one_regression_ccllt-i...             0.072781
#
#                                                     FWI_Global_SCORE_HIGH  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...               0.106334
# GRU_search_full_10_0_all_one_classification_flwk                 0.110128
# GRU_search_full_10_0_all_one_classification_wei...               0.123720
# GRU_search_full_10_0_all_one_classification_wkloss               0.208484
# GRU_search_full_10_0_all_one_classification_bce...               0.148364
# GRU_search_full_10_0_all_one_classification_fl                   0.123433
# GRU_search_full_10_0_all_one_regression_cll                      0.168165
# GRU_search_full_10_0_all_one_regression_ccllt-i...               0.159041
#
#                                                     FWI_Global_SCORE_LOW  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...              0.199790
# GRU_search_full_10_0_all_one_classification_flwk                0.070417
# GRU_search_full_10_0_all_one_classification_wei...              0.174104
# GRU_search_full_10_0_all_one_classification_wkloss              0.147810
# GRU_search_full_10_0_all_one_classification_bce...              0.044408
# GRU_search_full_10_0_all_one_classification_fl                  0.127211
# GRU_search_full_10_0_all_one_regression_cll                     0.236271
# GRU_search_full_10_0_all_one_regression_ccllt-i...              0.158721
#
#                                                     FWI_Global_SCORE_MIN_CLASS  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...                         1.0
# GRU_search_full_10_0_all_one_classification_flwk                           1.0
# GRU_search_full_10_0_all_one_classification_wei...                         1.0
# GRU_search_full_10_0_all_one_classification_wkloss                         1.0
# GRU_search_full_10_0_all_one_classification_bce...                         1.0
# GRU_search_full_10_0_all_one_classification_fl                             1.0
# GRU_search_full_10_0_all_one_regression_cll                                1.0
# GRU_search_full_10_0_all_one_regression_ccllt-i...                         1.0
#
#                                                     FWI_Global_RECALL  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...           0.834437
# GRU_search_full_10_0_all_one_classification_flwk             0.778146
# GRU_search_full_10_0_all_one_classification_wei...           0.841060
# GRU_search_full_10_0_all_one_classification_wkloss           0.960265
# GRU_search_full_10_0_all_one_classification_bce...           0.831126
# GRU_search_full_10_0_all_one_classification_fl               0.794702
# GRU_search_full_10_0_all_one_regression_cll                  0.900662
# GRU_search_full_10_0_all_one_regression_ccllt-i...           0.910596
#
#                                                     AGG_FWI_Global  ...  \
# Model                                                               ...
# GRU_search_full_10_0_all_one_classification_flw...       -0.124914  ...
# GRU_search_full_10_0_all_one_classification_flwk         -0.137535  ...
# GRU_search_full_10_0_all_one_classification_wei...       -0.104737  ...
# GRU_search_full_10_0_all_one_classification_wkloss        0.114528  ...
# GRU_search_full_10_0_all_one_classification_bce...       -0.086132  ...
# GRU_search_full_10_0_all_one_classification_fl           -0.114879  ...
# GRU_search_full_10_0_all_one_regression_cll               0.228939  ...
# GRU_search_full_10_0_all_one_regression_ccllt-i...        0.072926  ...
#
#                                                     AGG_FWI_25  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...   -0.126161
# GRU_search_full_10_0_all_one_classification_flwk      0.364946
# GRU_search_full_10_0_all_one_classification_wei...    0.094934
# GRU_search_full_10_0_all_one_classification_wkloss   -0.192917
# GRU_search_full_10_0_all_one_classification_bce...   -0.133319
# GRU_search_full_10_0_all_one_classification_fl        0.279979
# GRU_search_full_10_0_all_one_regression_cll          -0.332606
# GRU_search_full_10_0_all_one_regression_ccllt-i...    0.331698
#
#                                                     DFE_6_SCORE_k1  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...        0.551006
# GRU_search_full_10_0_all_one_classification_flwk         -0.151153
# GRU_search_full_10_0_all_one_classification_wei...        0.511822
# GRU_search_full_10_0_all_one_classification_wkloss       -0.941874
# GRU_search_full_10_0_all_one_classification_bce...        0.082543
# GRU_search_full_10_0_all_one_classification_fl            0.249886
# GRU_search_full_10_0_all_one_regression_cll              -1.124802
# GRU_search_full_10_0_all_one_regression_ccllt-i...        0.138170
#
#                                                     DFE_6_SCORE_k2  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...        0.000000
# GRU_search_full_10_0_all_one_classification_flwk          0.000000
# GRU_search_full_10_0_all_one_classification_wei...        0.000000
# GRU_search_full_10_0_all_one_classification_wkloss       -0.751337
# GRU_search_full_10_0_all_one_classification_bce...        0.000000
# GRU_search_full_10_0_all_one_classification_fl            0.000000
# GRU_search_full_10_0_all_one_regression_cll              -0.454667
# GRU_search_full_10_0_all_one_regression_ccllt-i...        0.263880
#
#                                                     DFE_6_SCORE_k3  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...        0.014891
# GRU_search_full_10_0_all_one_classification_flwk          0.060329
# GRU_search_full_10_0_all_one_classification_wei...       -0.035639
# GRU_search_full_10_0_all_one_classification_wkloss       -0.474974
# GRU_search_full_10_0_all_one_classification_bce...        0.052248
# GRU_search_full_10_0_all_one_classification_fl            0.070129
# GRU_search_full_10_0_all_one_regression_cll              -0.484391
# GRU_search_full_10_0_all_one_regression_ccllt-i...        0.423025
#
#                                                     DFE_6_SCORE_k4  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...        0.122637
# GRU_search_full_10_0_all_one_classification_flwk          0.038078
# GRU_search_full_10_0_all_one_classification_wei...        0.093371
# GRU_search_full_10_0_all_one_classification_wkloss        0.089156
# GRU_search_full_10_0_all_one_classification_bce...        0.058337
# GRU_search_full_10_0_all_one_classification_fl            0.106255
# GRU_search_full_10_0_all_one_regression_cll               0.000000
# GRU_search_full_10_0_all_one_regression_ccllt-i...        0.000000
#
#                                                     DFE_6_SCORE_HIGH  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...          0.137528
# GRU_search_full_10_0_all_one_classification_flwk            0.098407
# GRU_search_full_10_0_all_one_classification_wei...          0.057732
# GRU_search_full_10_0_all_one_classification_wkloss         -0.385818
# GRU_search_full_10_0_all_one_classification_bce...          0.110585
# GRU_search_full_10_0_all_one_classification_fl              0.176384
# GRU_search_full_10_0_all_one_regression_cll                -0.484391
# GRU_search_full_10_0_all_one_regression_ccllt-i...          0.423025
#
#                                                     DFE_6_SCORE_LOW  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...         0.551006
# GRU_search_full_10_0_all_one_classification_flwk          -0.151153
# GRU_search_full_10_0_all_one_classification_wei...         0.511822
# GRU_search_full_10_0_all_one_classification_wkloss        -1.693211
# GRU_search_full_10_0_all_one_classification_bce...         0.082543
# GRU_search_full_10_0_all_one_classification_fl             0.249886
# GRU_search_full_10_0_all_one_regression_cll               -1.579469
# GRU_search_full_10_0_all_one_regression_ccllt-i...         0.402051
#
#                                                     DFE_6_SCORE_MIN_CLASS  \
# Model
# GRU_search_full_10_0_all_one_classification_flw...                    1.0
# GRU_search_full_10_0_all_one_classification_flwk                      1.0
# GRU_search_full_10_0_all_one_classification_wei...                    1.0
# GRU_search_full_10_0_all_one_classification_wkloss                    1.0
# GRU_search_full_10_0_all_one_classification_bce...                    1.0
# GRU_search_full_10_0_all_one_classification_fl                        1.0
# GRU_search_full_10_0_all_one_regression_cll                           1.0
# GRU_search_full_10_0_all_one_regression_ccllt-i...                    1.0
#
#                                                     DFE_6_RECALL  AGG_DFE_6
# Model
# GRU_search_full_10_0_all_one_classification_flw...      0.832370   0.000127
# GRU_search_full_10_0_all_one_classification_flwk        0.751445  -0.422729
# GRU_search_full_10_0_all_one_classification_wei...      0.890173  -0.065743
# GRU_search_full_10_0_all_one_classification_wkloss      0.994220  -0.454119
# GRU_search_full_10_0_all_one_classification_bce...      0.843931  -0.195400
# GRU_search_full_10_0_all_one_classification_fl          0.774566   0.026608
# GRU_search_full_10_0_all_one_regression_cll             0.867052  -0.606192
# GRU_search_full_10_0_all_one_regression_ccllt-i...      0.907514   0.327390
#
# [8 rows x 46 columns]

# %%
# --- Visualization: Top-2 Models by AGG score per Target ---
import pandas as pd
import matplotlib.pyplot as plt

dept = [1, 6, 25]

for d in dept:
        
    # We iterate over the simple names used in all_target_results
    for simple_name in ['Fire', 'Ressource', 'Time']:

        if d == 1 and simple_name == 'Time':
            continue

        if simple_name not in all_target_results:
            print(f"[{simple_name}] not found in all_target_results — skipping visualization.")
            continue
        
        res = all_target_results[simple_name]
        df_res = res.get('scores_lh_plot', pd.DataFrame())
        if df_res.empty: continue
        
        # Selection of top 2 models by AGG
        agg_candidates = [c for c in df_res.columns if 'AGG' in c]
        if not agg_candidates: continue
        
        agg_col = f'AGG_FWI_{d}'

        # Identify top 2 models
        #top_models = df_res.sort_values(agg_col, ascending=False).head(2)
        
        df_res = df_res.reset_index()
        
        top_models = df_res[(df_res['Model'].str.contains('ccllt')) | (df_res['Model'].str.contains('flwk-id')) | (df_res['Model'].str.contains('cll'))].set_index('Model')
        
        print(f"\n{'='*70}\n  VISUALIZING TOP-2 MODELS FOR: {simple_name} (sorted by {agg_col})\n{'='*70}")
        
        sc = scorers.get(simple_name)
        if sc is None:
            print(f"Scorer not found for {simple_name}"); continue
        
        # Find the short_key from SIMPLE_NAMES inverse
        short_key = None
        for k, v in SIMPLE_NAMES.items():
            if v == simple_name:
                short_key = k
                break
        
        # Use _INV_CLLT_TARGET_MAP to get target_key (long name)
        target_key = _INV_CLLT_TARGET_MAP.get(short_key)
        if target_key is None or target_key not in gt_dfs:
            print(f"Ground truth link not found for {simple_name} (short_key: {short_key})"); continue

        gt_df_orig = gt_dfs[target_key].copy()
        gt_df_orig = gt_df_orig[gt_df_orig['departement'] == d]
        gt_df_orig['date'] = gt_df_orig['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
        gt_df_orig['date'] = pd.to_datetime(gt_df_orig['date'])
        gt_df_orig['num_zone'] = gt_df_orig['num_zone'].astype(int)

        for model_name, row in top_models.iterrows():
            print(f"\n>>> Plotting Fit for {model_name} (AGG: {row[agg_col]:.4f})")
            
            # Get predictions
            models_dict = all_data_frames.get(target_key, {})
            df_pred = models_dict.get(model_name)
            if df_pred is None:
                print(f"  Predictions not found for {model_name}"); continue
            
            df_p = df_pred.copy()
            df_p['date'] = df_p['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
            df_p['date'] = pd.to_datetime(df_p['date'])
            df_p['num_zone'] = df_p['num_zone'].astype(int)

            # Merge for scoring. Use suffixes to avoid renaming the model's prediction columns.
            # We need the ground truth from gt_df_orig, so we take it from the '_gt' columns.
            merged = pd.merge(df_p, gt_df_orig, on=['date', 'num_zone'], how='inner', suffixes=('', '_gt'))
            merged = merged[merged['date'].dt.year == 2023]

            if not merged.empty:
                # Use target_key_gt as the ground truth classes for the scorer
                # Use risk_score as the model's predicted risk class
                sc._plot(merged['risk_score'], merged[f"{target_key}_gt"], merged['date'], merged['num_zone'], 
                        title=f"{simple_name} Monotonic Fit - {model_name} - dept {d}")
            else:
                print("  Empty merge for 2023 data — check date alignment.")
# Out:
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Fire (sorted by AGG_FWI_1)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_cll (AGG: 0.3320)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: 0.3332)
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Ressource (sorted by AGG_FWI_1)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_cll (AGG: 0.3851)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: 0.4307)
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Fire (sorted by AGG_FWI_6)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_cll (AGG: -0.1516)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: 0.1577)
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Ressource (sorted by AGG_FWI_6)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_cll (AGG: 0.0984)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: 0.2650)
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Time (sorted by AGG_FWI_6)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_cll (AGG: -0.4081)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: 0.3333)
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Fire (sorted by AGG_FWI_25)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_cll (AGG: 0.1447)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: 0.5209)
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Ressource (sorted by AGG_FWI_25)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_cll (AGG: 0.6667)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: 0.8331)
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Time (sorted by AGG_FWI_25)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_cll (AGG: -0.3326)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: 0.3317)

# %%
# --- Per-Target comparison tables: Models vs FWI Baseline (2023, dept from MODE) ---
import pandas as pd
import numpy as np

# Département extrait depuis MODE ('06' -> 6)

dept = [1, 25, "Global"]

all_dept_tables = []
    
for d in dept:
    if d == 'Global':
        BASELINE_DATASET_KEY = year_test
    else:
        BASELINE_DATASET_KEY = f"{year_test}_{d}"

    def load_fwi_baseline(target_name):
        """
        Load FWI baseline for target_name from path_baseline/fwi_scores_{target_name}.csv.
        Uses row Dataset == '2023_{DEPT}', fallback to 'Global'.
        Returns dict with score_k1..4, recall, score_min_class or None.
        """
        fname = path_baseline / f"fwi_scores_summer_{target_name}.csv"
        try:
            bdf = pd.read_csv(fname)
        except FileNotFoundError:
            print(f"  baseline file not found: {fname}")
            return None
        row = bdf[bdf['Dataset'] == BASELINE_DATASET_KEY]
        if row.empty:
            print('ERRROROROR')
            raise ValueError
            row = bdf[bdf['Dataset'] == 'Global']
            if not row.empty:
                print(f"  [{target_name}] no row for {BASELINE_DATASET_KEY!r}, using 'Global'")
        if row.empty:
            print(f"  [{target_name}] no baseline row found (tried {BASELINE_DATASET_KEY!r} and 'Global')")
            return None

        data = row.iloc[0]
        return {
            'score_k1':       float(data.get('k1', np.nan)),
            'score_k2':       float(data.get('k2', np.nan)),
            'score_k3':       float(data.get('k3', np.nan)),
            'score_k4':       float(data.get('k4', np.nan)),
            'recall':         float(data.get('recall', np.nan)),
            'score_min_class': float(data.get('score_min_class', np.nan)),
        }

    def get_val(row, *candidates):
        for c in candidates:
            if c in row.index and pd.notna(row[c]):
                return float(row[c])
        return np.nan

    DISPLAY_COLS = [
        ('score_k1',        'k1'),
        ('score_k2',        'k2'),
        ('score_k3',        'k3'),
        ('score_k4',        'k4'),
        ('recall',          'recall'),
        ('score_min_class', 'min_class'),
        ('agg',             'AGG'),
    ]

    for target in ['Fire', 'Ressource', 'Time']:
        
        if d == 1 and target == 'Time':
            continue

        if target not in all_target_results:
            print(f"[{target}] not in all_target_results — skipping.")
            continue

        scores_lh = all_target_results[target].get('scores_lh_plot', pd.DataFrame())
        if scores_lh.empty:
            print(f"[{target}] scores_lh_plot empty — skipping.")
            continue

        ref = load_fwi_baseline(target)
        rows = []

        # --- Baseline row ---
        if ref:
            base_row = {'Model': f'Baseline FWI ({BASELINE_DATASET_KEY})'}
            for sk, label in DISPLAY_COLS:
                if sk == 'agg':
                    base_row[label] = np.nan
                else:
                    base_row[label] = ref.get(sk, np.nan)
            rows.append(base_row)
        else:
            print(f"  [{target}] baseline not loaded.")

        # --- Model rows ---
        for model_name, row in scores_lh.iterrows():
            model_row = {'Model': model_name}
            for sk, label in DISPLAY_COLS:
                if sk == 'agg':
                    val = get_val(row, f'AGG_FWI_{d}')
                elif sk == 'recall':
                    val = get_val(row, f'FWI_{d}_RECALL', 'RECALL')
                elif sk == 'score_min_class':
                    val = get_val(row, f'FWI_{d}_SCORE_MIN_CLASS', 'SCORE_MIN_CLASS')
                else:
                    k = sk[-1]
                    val = get_val(row,
                        f'FWI_{d}_SCORE_k{k}',
                        f'SCORE_k{k}',
                    )
                model_row[label] = val
            rows.append(model_row)

        df_table = pd.DataFrame(rows)
        df_table['Target'] = target

        if d != 'Global':
            all_dept_tables.append(df_table)
            
        print(f"\n{'═'*65}")
        print(f"  {target}  —  baseline: {BASELINE_DATASET_KEY}")
        print(f"{'═'*65}")
        print(df_table.to_markdown(floatfmt=".4f"))
        print()
        
# --- Print Average Table ---
if all_dept_tables:
    df_avg = pd.concat(all_dept_tables)
    tars = df_avg['Target'].unique()
    for target in tars:
        df_avg_tar = df_avg[df_avg['Target'] == target]
        df_avg_tar.drop('Target', inplace=True, axis=1)
        df_avg_tar = df_avg_tar.groupby('Model').mean()
        
        # Sort to keep the baseline at the top if it's there
        baseline_index = [i for i in df_avg_tar.index if 'Baseline' in i]
        other_index = [i for i in df_avg_tar.index if 'Baseline' not in i]
        df_avg_tar = df_avg_tar.reindex(baseline_index + other_index)

        print(f"\n{'═'*65}")
        print(f"  {target}  —  Average (Depts: 1, 6, 25)")
        print(f"{'═'*65}")
        print(df_avg_tar.to_markdown(floatfmt=".4f"))
        print()
        
save_comparison_csv(fwi_results_all, 'fwi_summer', path_baseline)
print("\nDone.")
# Out:
# ═════════════════════════════════════════════════════════════════
#   Fire  —  baseline: 2023_1
# ═════════════════════════════════════════════════════════════════
# |    | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG | Target   |
# |---:|:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|:---------|
# |  0 | Baseline FWI (2023_1)                                                | -0.0197 |  0.0812 |  0.1020 |  0.0799 |   0.7853 |      1.0000 | nan      | Fire     |
# |  1 | GRU_search_full_10_0_all_one_regression_pdegpd                       |  0.2749 |  0.3995 |  0.0000 |  0.0000 |   0.7607 |      1.0000 |   0.2604 | Fire     |
# |  2 | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.0725 |  0.1158 |  0.1515 |  0.2424 |   0.8221 |      1.0000 |   0.6042 | Fire     |
# |  3 | GRU_search_full_10_0_all_one_classification_flwk                     |  0.2037 |  0.2516 |  0.3160 |  0.4133 |   0.8466 |      1.0000 |   0.6736 | Fire     |
# |  4 | GRU_search_full_10_0_all_one_classification_bceloss                  |  0.0349 |  0.0000 |  0.0267 |  0.0285 |   0.7117 |      1.0000 |   0.2400 | Fire     |
# |  5 | GRU_search_full_10_0_all_one_classification_fl                       | -0.1669 | -0.1317 | -0.1289 | -0.0795 |   0.9387 |      1.0000 |  -0.2765 | Fire     |
# |  6 | GRU_search_full_10_0_all_one_regression_cll                          |  0.1243 |  0.1361 |  0.1493 |  0.0000 |   0.6871 |      1.0000 |   0.3320 | Fire     |
# |  7 | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} | -0.0046 |  0.0454 |  0.0488 |  0.0496 |   0.9509 |      1.0000 |   0.3332 | Fire     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Ressource  —  baseline: 2023_1
# ═════════════════════════════════════════════════════════════════
# |    | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG | Target    |
# |---:|:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|:----------|
# |  0 | Baseline FWI (2023_1)                                                | -0.0658 | -0.0175 | -0.0173 | -0.0488 |   0.7853 |      1.0000 | nan      | Ressource |
# |  1 | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -0.2206 | -0.0468 |  0.0196 | -0.0249 |   0.9387 |      1.0000 |  -0.0334 | Ressource |
# |  2 | GRU_search_full_10_0_all_one_classification_flwk                     | -0.1578 | -0.1109 | -0.0854 |  0.0205 |   0.8589 |      1.0000 |  -0.1936 | Ressource |
# |  3 | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     |  0.1712 |  0.0000 |  0.0586 |  0.0758 |   0.6196 |      1.0000 |   0.4256 | Ressource |
# |  4 | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.0141 |  0.0472 |  0.0510 |  0.0582 |   0.8160 |      1.0000 |   0.4258 | Ressource |
# |  5 | GRU_search_full_10_0_all_one_classification_bceloss                  | -0.9081 |  0.0000 | -0.0300 | -0.1643 |   0.9264 |      1.0000 |  -0.1429 | Ressource |
# |  6 | GRU_search_full_10_0_all_one_classification_fl                       | -0.7579 | -0.3396 |  0.0573 |  0.0058 |   0.9080 |      1.0000 |  -0.2488 | Ressource |
# |  7 | GRU_search_full_10_0_all_one_regression_cll                          |  0.1665 |  0.2288 |  0.2795 |  0.0000 |   0.6442 |      1.0000 |   0.3851 | Ressource |
# |  8 | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0065 |  0.0496 |  0.0738 |  0.0539 |   0.8282 |      1.0000 |   0.4307 | Ressource |
#
#
# ═════════════════════════════════════════════════════════════════
#   Fire  —  baseline: 2023_25
# ═════════════════════════════════════════════════════════════════
# |    | Model                                                                |      k1 |      k2 |     k3 |      k4 |   recall |   min_class |      AGG | Target   |
# |---:|:---------------------------------------------------------------------|--------:|--------:|-------:|--------:|---------:|------------:|---------:|:---------|
# |  0 | Baseline FWI (2023_25)                                               | -0.1526 |  0.0249 | 0.0000 |  0.0000 |   0.5877 |      1.0000 | nan      | Fire     |
# |  1 | GRU_search_full_10_0_all_one_regression_pdegpd                       |  0.1628 |  0.2883 | 0.0000 |  0.0000 |   0.7456 |      1.0000 |   0.2232 | Fire     |
# |  2 | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.0646 |  0.0921 | 0.0957 |  0.0894 |   0.7719 |      1.0000 |   0.3010 | Fire     |
# |  3 | GRU_search_full_10_0_all_one_classification_flwk                     |  0.0909 |  0.0970 | 0.1891 |  0.3665 |   0.7807 |      1.0000 |   0.4868 | Fire     |
# |  4 | GRU_search_full_10_0_all_one_classification_bceloss                  |  0.1047 |  0.0000 | 0.0427 |  0.0567 |   0.6667 |      1.0000 |   0.0570 | Fire     |
# |  5 | GRU_search_full_10_0_all_one_classification_fl                       | -0.1756 | -0.0462 | 0.0142 | -0.0529 |   0.8158 |      1.0000 |  -0.4331 | Fire     |
# |  6 | GRU_search_full_10_0_all_one_regression_cll                          |  0.0648 |  0.0778 | 0.1052 |  0.0000 |   0.6491 |      1.0000 |   0.1447 | Fire     |
# |  7 | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0891 |  0.1206 | 0.1591 |  0.2144 |   0.9035 |      1.0000 |   0.5209 | Fire     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Ressource  —  baseline: 2023_25
# ═════════════════════════════════════════════════════════════════
# |    | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG | Target    |
# |---:|:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|:----------|
# |  0 | Baseline FWI (2023_25)                                               |  0.0000 |  0.0000 |  0.0000 |  0.0000 |   0.0000 |      1.0000 | nan      | Ressource |
# |  1 | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -1.4989 | -0.6430 |  0.0773 | -0.1281 |   0.8725 |      1.0000 |  -0.2014 | Ressource |
# |  2 | GRU_search_full_10_0_all_one_classification_flwk                     | -0.3269 | -0.2776 | -0.1441 |  0.1752 |   0.7255 |      1.0000 |  -0.1569 | Ressource |
# |  3 | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     |  0.0782 |  0.0000 |  0.3103 |  0.2748 |   0.6961 |      1.0000 |   0.6070 | Ressource |
# |  4 | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.0157 |  0.1845 |  0.2439 |  0.2302 |   0.6569 |      1.0000 |   0.6787 | Ressource |
# |  5 | GRU_search_full_10_0_all_one_classification_bceloss                  | -2.3412 |  0.0000 |  0.0847 | -0.1429 |   0.9902 |      1.0000 |  -0.0337 | Ressource |
# |  6 | GRU_search_full_10_0_all_one_classification_fl                       | -2.0244 |  0.0000 |  0.1873 |  0.0554 |   0.8725 |      1.0000 |   0.2429 | Ressource |
# |  7 | GRU_search_full_10_0_all_one_regression_cll                          |  0.5584 |  0.7377 |  0.7109 |  0.0000 |   0.5588 |      1.0000 |   0.6667 | Ressource |
# |  8 | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.4012 |  0.4690 |  0.4701 |  0.4704 |   0.7941 |      1.0000 |   0.8331 | Ressource |
#
#
# ═════════════════════════════════════════════════════════════════
#   Time  —  baseline: 2023_25
# ═════════════════════════════════════════════════════════════════
# |    | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG | Target   |
# |---:|:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|:---------|
# |  0 | Baseline FWI (2023_25)                                               |  0.0000 |  0.0000 |  0.0000 |  0.0000 |   0.0000 |      1.0000 | nan      | Time     |
# |  1 | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -0.5253 |  0.0000 |  0.0014 | -0.1023 |   0.8641 |      1.0000 |  -0.1262 | Time     |
# |  2 | GRU_search_full_10_0_all_one_classification_flwk                     |  0.0396 |  0.0000 |  0.0436 |  0.0428 |   0.7961 |      1.0000 |   0.3649 | Time     |
# |  3 | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | -0.3531 |  0.0000 |  0.0465 |  0.0135 |   0.7961 |      1.0000 |   0.0949 | Time     |
# |  4 | GRU_search_full_10_0_all_one_classification_wkloss                   | -0.3073 | -0.1850 | -0.1232 |  0.0747 |   0.8932 |      1.0000 |  -0.1929 | Time     |
# |  5 | GRU_search_full_10_0_all_one_classification_bceloss                  | -1.0348 |  0.0000 |  0.0141 | -0.1741 |   0.8544 |      1.0000 |  -0.1333 | Time     |
# |  6 | GRU_search_full_10_0_all_one_classification_fl                       |  0.0435 |  0.0000 |  0.0103 |  0.0170 |   0.8447 |      1.0000 |   0.2800 | Time     |
# |  7 | GRU_search_full_10_0_all_one_regression_cll                          | -0.5597 | -0.4610 | -0.3089 |  0.0000 |   0.9515 |      1.0000 |  -0.3326 | Time     |
# |  8 | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0087 |  0.0394 |  0.0589 |  0.0000 |   0.9709 |      1.0000 |   0.3317 | Time     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Fire  —  baseline: 2023
# ═════════════════════════════════════════════════════════════════
# |    | Model                                                                |     k1 |     k2 |     k3 |     k4 |   recall |   min_class |      AGG | Target   |
# |---:|:---------------------------------------------------------------------|-------:|-------:|-------:|-------:|---------:|------------:|---------:|:---------|
# |  0 | Baseline FWI (2023)                                                  | 0.1341 | 0.1660 | 0.1779 | 0.1644 |   0.6972 |      1.0000 | nan      | Fire     |
# |  1 | GRU_search_full_10_0_all_one_regression_pdegpd                       | 0.3351 | 0.4870 | 0.0000 | 0.0000 |   0.6939 |      1.0000 |   0.0465 | Fire     |
# |  2 | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | 0.1742 | 0.2023 | 0.2305 | 0.3218 |   0.8050 |      1.0000 |   0.3136 | Fire     |
# |  3 | GRU_search_full_10_0_all_one_classification_flwk                     | 0.2250 | 0.2608 | 0.3235 | 0.3902 |   0.7484 |      1.0000 |   0.4821 | Fire     |
# |  4 | GRU_search_full_10_0_all_one_classification_bceloss                  | 0.1779 | 0.0000 | 0.0444 | 0.0745 |   0.5996 |      1.0000 |  -0.2998 | Fire     |
# |  5 | GRU_search_full_10_0_all_one_classification_fl                       | 0.0487 | 0.0854 | 0.0978 | 0.0830 |   0.8889 |      1.0000 |  -0.2673 | Fire     |
# |  6 | GRU_search_full_10_0_all_one_regression_cll                          | 0.1551 | 0.1719 | 0.2085 | 0.0000 |   0.6205 |      1.0000 |  -0.0446 | Fire     |
# |  7 | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} | 0.1185 | 0.1647 | 0.1885 | 0.1677 |   0.9245 |      1.0000 |   0.0712 | Fire     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Ressource  —  baseline: 2023
# ═════════════════════════════════════════════════════════════════
# |    | Model                                                                |     k1 |     k2 |     k3 |     k4 |   recall |   min_class |      AGG | Target    |
# |---:|:---------------------------------------------------------------------|-------:|-------:|-------:|-------:|---------:|------------:|---------:|:----------|
# |  0 | Baseline FWI (2023)                                                  | 0.1722 | 0.2189 | 0.2563 | 0.2903 |   0.7348 |      1.0000 | nan      | Ressource |
# |  1 | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | 0.2466 | 0.1823 | 0.2004 | 0.1949 |   0.8556 |      1.0000 |   0.2657 | Ressource |
# |  2 | GRU_search_full_10_0_all_one_classification_flwk                     | 0.2617 | 0.2667 | 0.2692 | 0.2711 |   0.7586 |      1.0000 |   0.4021 | Ressource |
# |  3 | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | 0.3764 | 0.0000 | 0.2274 | 0.2502 |   0.5560 |      1.0000 |   0.0496 | Ressource |
# |  4 | GRU_search_full_10_0_all_one_classification_wkloss                   | 0.1832 | 0.2262 | 0.2575 | 0.2361 |   0.8017 |      1.0000 |   0.3327 | Ressource |
# |  5 | GRU_search_full_10_0_all_one_classification_bceloss                  | 0.4035 | 0.0000 | 0.1601 | 0.1973 |   0.9375 |      1.0000 |   0.0295 | Ressource |
# |  6 | GRU_search_full_10_0_all_one_classification_fl                       | 0.3504 | 0.2519 | 0.2448 | 0.2604 |   0.8642 |      1.0000 |   0.4031 | Ressource |
# |  7 | GRU_search_full_10_0_all_one_regression_cll                          | 0.5238 | 0.6059 | 0.6693 | 0.0000 |   0.4698 |      1.0000 |   0.3076 | Ressource |
# |  8 | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} | 0.1786 | 0.2413 | 0.2776 | 0.2547 |   0.6961 |      1.0000 |   0.3394 | Ressource |
#
#
# ═════════════════════════════════════════════════════════════════
#   Time  —  baseline: 2023
# ═════════════════════════════════════════════════════════════════
# |    | Model                                                                |     k1 |     k2 |     k3 |     k4 |   recall |   min_class |      AGG | Target   |
# |---:|:---------------------------------------------------------------------|-------:|-------:|-------:|-------:|---------:|------------:|---------:|:---------|
# |  0 | Baseline FWI (2023)                                                  | 0.0383 | 0.0802 | 0.0856 | 0.1000 |   0.6935 |      1.0000 | nan      | Time     |
# |  1 | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | 0.1998 | 0.0000 | 0.0368 | 0.0695 |   0.8344 |      1.0000 |  -0.1249 | Time     |
# |  2 | GRU_search_full_10_0_all_one_classification_flwk                     | 0.0704 | 0.0000 | 0.0533 | 0.0568 |   0.7781 |      1.0000 |  -0.1375 | Time     |
# |  3 | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | 0.1741 | 0.0000 | 0.0493 | 0.0744 |   0.8411 |      1.0000 |  -0.1047 | Time     |
# |  4 | GRU_search_full_10_0_all_one_classification_wkloss                   | 0.0678 | 0.0800 | 0.0942 | 0.1143 |   0.9603 |      1.0000 |   0.1145 | Time     |
# |  5 | GRU_search_full_10_0_all_one_classification_bceloss                  | 0.0444 | 0.0000 | 0.0775 | 0.0709 |   0.8311 |      1.0000 |  -0.0861 | Time     |
# |  6 | GRU_search_full_10_0_all_one_classification_fl                       | 0.1272 | 0.0000 | 0.0544 | 0.0690 |   0.7947 |      1.0000 |  -0.1149 | Time     |
# |  7 | GRU_search_full_10_0_all_one_regression_cll                          | 0.0908 | 0.1454 | 0.1682 | 0.0000 |   0.9007 |      1.0000 |   0.2289 | Time     |
# |  8 | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} | 0.0652 | 0.0935 | 0.0863 | 0.0728 |   0.9106 |      1.0000 |   0.0729 | Time     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Fire  —  Average (Depts: 1, 6, 25)
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|
# | Baseline FWI (2023_1)                                                | -0.0197 |  0.0812 |  0.1020 |  0.0799 |   0.7853 |      1.0000 | nan      |
# | Baseline FWI (2023_25)                                               | -0.1526 |  0.0249 |  0.0000 |  0.0000 |   0.5877 |      1.0000 | nan      |
# | GRU_search_full_10_0_all_one_classification_bceloss                  |  0.0698 |  0.0000 |  0.0347 |  0.0426 |   0.6892 |      1.0000 |   0.1485 |
# | GRU_search_full_10_0_all_one_classification_fl                       | -0.1713 | -0.0890 | -0.0574 | -0.0662 |   0.8772 |      1.0000 |  -0.3548 |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.1473 |  0.1743 |  0.2525 |  0.3899 |   0.8137 |      1.0000 |   0.5802 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.0685 |  0.1039 |  0.1236 |  0.1659 |   0.7970 |      1.0000 |   0.4526 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0423 |  0.0830 |  0.1040 |  0.1320 |   0.9272 |      1.0000 |   0.4270 |
# | GRU_search_full_10_0_all_one_regression_cll                          |  0.0945 |  0.1070 |  0.1272 |  0.0000 |   0.6681 |      1.0000 |   0.2383 |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       |  0.2189 |  0.3439 |  0.0000 |  0.0000 |   0.7532 |      1.0000 |   0.2418 |
#
#
# ═════════════════════════════════════════════════════════════════
#   Ressource  —  Average (Depts: 1, 6, 25)
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|
# | Baseline FWI (2023_1)                                                | -0.0658 | -0.0175 | -0.0173 | -0.0488 |   0.7853 |      1.0000 | nan      |
# | Baseline FWI (2023_25)                                               |  0.0000 |  0.0000 |  0.0000 |  0.0000 |   0.0000 |      1.0000 | nan      |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -1.6247 |  0.0000 |  0.0274 | -0.1536 |   0.9583 |      1.0000 |  -0.0883 |
# | GRU_search_full_10_0_all_one_classification_fl                       | -1.3911 | -0.1698 |  0.1223 |  0.0306 |   0.8903 |      1.0000 |  -0.0030 |
# | GRU_search_full_10_0_all_one_classification_flwk                     | -0.2424 | -0.1943 | -0.1147 |  0.0979 |   0.7922 |      1.0000 |  -0.1753 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -0.8598 | -0.3449 |  0.0484 | -0.0765 |   0.9056 |      1.0000 |  -0.1174 |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     |  0.1247 |  0.0000 |  0.1844 |  0.1753 |   0.6579 |      1.0000 |   0.5163 |
# | GRU_search_full_10_0_all_one_classification_wkloss                   |  0.0149 |  0.1159 |  0.1475 |  0.1442 |   0.7364 |      1.0000 |   0.5522 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.2039 |  0.2593 |  0.2720 |  0.2622 |   0.8112 |      1.0000 |   0.6319 |
# | GRU_search_full_10_0_all_one_regression_cll                          |  0.3624 |  0.4833 |  0.4952 |  0.0000 |   0.6015 |      1.0000 |   0.5259 |
#
#
# ═════════════════════════════════════════════════════════════════
#   Time  —  Average (Depts: 1, 6, 25)
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |      k4 |   recall |   min_class |      AGG |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|--------:|---------:|------------:|---------:|
# | Baseline FWI (2023_25)                                               |  0.0000 |  0.0000 |  0.0000 |  0.0000 |   0.0000 |      1.0000 | nan      |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -1.0348 |  0.0000 |  0.0141 | -0.1741 |   0.8544 |      1.0000 |  -0.1333 |
# | GRU_search_full_10_0_all_one_classification_fl                       |  0.0435 |  0.0000 |  0.0103 |  0.0170 |   0.8447 |      1.0000 |   0.2800 |
# | GRU_search_full_10_0_all_one_classification_flwk                     |  0.0396 |  0.0000 |  0.0436 |  0.0428 |   0.7961 |      1.0000 |   0.3649 |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -0.5253 |  0.0000 |  0.0014 | -0.1023 |   0.8641 |      1.0000 |  -0.1262 |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | -0.3531 |  0.0000 |  0.0465 |  0.0135 |   0.7961 |      1.0000 |   0.0949 |
# | GRU_search_full_10_0_all_one_classification_wkloss                   | -0.3073 | -0.1850 | -0.1232 |  0.0747 |   0.8932 |      1.0000 |  -0.1929 |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0087 |  0.0394 |  0.0589 |  0.0000 |   0.9709 |      1.0000 |   0.3317 |
# | GRU_search_full_10_0_all_one_regression_cll                          | -0.5597 | -0.4610 | -0.3089 |  0.0000 |   0.9515 |      1.0000 |  -0.3326 |
#
# Index(['Model', 'Target', 'FWI_Global_SCORE_k1', 'FWI_Global_SCORE_k2',
#        'FWI_Global_SCORE_k3', 'FWI_Global_SCORE_k4', 'FWI_Global_SCORE_HIGH',
#        'FWI_Global_SCORE_LOW', 'FWI_Global_SCORE_MIN_CLASS',
#        'FWI_Global_RECALL', 'AGG_FWI_Global', 'FWI_1_SCORE_k1',
#        'FWI_1_SCORE_k2', 'FWI_1_SCORE_k3', 'FWI_1_SCORE_k4',
#        'FWI_1_SCORE_HIGH', 'FWI_1_SCORE_LOW', 'FWI_1_SCORE_MIN_CLASS',
#        'FWI_1_RECALL', 'AGG_FWI_1', 'FWI_6_SCORE_k1', 'FWI_6_SCORE_k2',
#        'FWI_6_SCORE_k3', 'FWI_6_SCORE_k4', 'FWI_6_SCORE_HIGH',
#        'FWI_6_SCORE_LOW', 'FWI_6_SCORE_MIN_CLASS', 'FWI_6_RECALL', 'AGG_FWI_6',
#        'FWI_25_SCORE_k1', 'FWI_25_SCORE_k2', 'FWI_25_SCORE_k3',
#        'FWI_25_SCORE_k4', 'FWI_25_SCORE_HIGH', 'FWI_25_SCORE_LOW',
#        'FWI_25_SCORE_MIN_CLASS', 'FWI_25_RECALL', 'AGG_FWI_25'],
#       dtype='object')
# Table de comparaison FWI_SUMMER sauvegardée dans : firemen2/comparison_fwi_summer_scores.csv
#
# Done.
# /tmp/ipykernel_1226066/1413328831.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg_tar.drop('Target', inplace=True, axis=1)
# /tmp/ipykernel_1226066/1413328831.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg_tar.drop('Target', inplace=True, axis=1)
# /tmp/ipykernel_1226066/1413328831.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avg_tar.drop('Target', inplace=True, axis=1)

# %%
# --- DFE comparison tables: Models vs DFE Baseline (été 2023, dept 06) ---
# DFE = Défense des Forêts contre l'Incendie, subset: été 2023 (mid-juin → fin sept), dept 6

import pandas as pd
import numpy as np

all_dept_tables = []

DFE_YEAR = year_test   # Dataset key in dfe_scores_*.csv

def load_dfe_baseline(target_name):
    """
    Load DFE baseline from path_baseline/dfe_scores_{target_name}.csv.
    Uses row Dataset == DFE_YEAR, fallback to 'Global'.
    """
    fname = path_baseline / f"dfe_scores_{target_name}.csv"
    try:
        bdf = pd.read_csv(fname)
    except FileNotFoundError:
        print(f"  DFE baseline file not found: {fname}")
        return None

    row = bdf[bdf['Dataset'] == DFE_YEAR]
    if row.empty:
        row = bdf[bdf['Dataset'] == 'Global']
        if not row.empty:
            print(f"  [{target_name}] no DFE row for {DFE_YEAR!r}, using 'Global'")
    if row.empty:
        print(f"  [{target_name}] no DFE baseline found")
        return None

    data = row.iloc[0]
    return {
        'score_k1':        float(data.get('k1', np.nan)),
        'score_k2':        float(data.get('k2', np.nan)),
        'score_k3':        float(data.get('k3', np.nan)),
        'score_k4':        float(data.get('k4', np.nan)),
        'recall':          float(data.get('recall', np.nan)),
        'score_min_class': float(data.get('score_min_class', np.nan)),
    }


def get_val(row, *candidates):
    for c in candidates:
        if c in row.index and pd.notna(row[c]):
            return float(row[c])
    return np.nan

DISPLAY_COLS = [
    ('score_k1',        'k1'),
    ('score_k2',        'k2'),
    ('score_k3',        'k3'),
    ('score_k4',        'k4'),
    ('recall',          'recall'),
    ('score_min_class', 'min_class'),
    ('agg',             'AGG_DFE'),
]

for target in ['Fire', 'Time', 'Ressource']:
    if target not in all_target_results:
        print(f"[{target}] not in all_target_results — skipping.")
        continue

    scores_lh = all_target_results[target].get('scores_lh_plot', pd.DataFrame())
    if scores_lh.empty:
        print(f"[{target}] scores_lh_plot empty — skipping.")
        continue

    ref = load_dfe_baseline(target)
    rows = []

    # --- Baseline row ---
    if ref:
        base_row = {'Model': f'Baseline DFE ({DFE_YEAR})'}
        for sk, label in DISPLAY_COLS:
            if sk == 'agg':
                base_row[label] = np.nan
            else:
                base_row[label] = ref.get(sk, np.nan)
        rows.append(base_row)

    # --- Model rows ---
    for model_name, row in scores_lh.iterrows():
        model_row = {'Model': model_name}
        for sk, label in DISPLAY_COLS:
            if sk == 'agg':
                # DFE AGG = summer dept 6 AGG
                val = get_val(row, 'AGG_DFE_6', 'AGG_DFE', 'AGG')
            elif sk == 'recall':
                val = get_val(row, 'DFE_6_RECALL', 'FWI_Global_RECALL', 'RECALL')
            elif sk == 'score_min_class':
                val = get_val(row, 'DFE_6_SCORE_MIN_CLASS', 'FWI_Global_SCORE_MIN_CLASS')
            else:
                k = sk[-1]
                val = get_val(row,
                    f'DFE_6_SCORE_k{k}',
                    f'FWI_Global_SCORE_k{k}',
                    f'SCORE_k{k}',
                )
            model_row[label] = val
        rows.append(model_row)

    df_table = pd.DataFrame(rows).set_index('Model')
    df_table['Target'] = target

    if d != 'Global':
        all_dept_tables.append(df_table)
    
    print(f"\n{'═'*65}")
    print(f"  {target}  —  DFE été {DFE_YEAR}, dept 6")
    print(f"{'═'*65}")
    print(df_table.to_markdown(floatfmt=".4f"))
    print()
    
# --- Print Average Table ---
if all_dept_tables:
    df_avg = pd.concat(all_dept_tables)
    tars = df_avg['Target'].unique()
    for target in tars:
        df_avg_tar = df_avg[df_avg['Target'] == target]
        df_avg_tar.drop('Target', inplace=True, axis=1)
        df_avg_tar = df_avg_tar.groupby('Model').mean()

        # Sort to keep the baseline at the top if it's there
        baseline_index = [i for i in df_avg_tar.index if 'Baseline' in i]
        other_index = [i for i in df_avg_tar.index if 'Baseline' not in i]
        df_avg_tar = df_avg_tar.reindex(baseline_index + other_index)

        print(f"\n{'═'*65}")
        print(f"  {target}  —  Average (Depts: 1, 6, 25)")
        print(f"{'═'*65}")
        print(df_avg_tar.to_markdown(floatfmt=".4f"))
        print()
        
save_comparison_csv(dfe_results_all, 'dfe', path_baseline)
# Out:
# ═════════════════════════════════════════════════════════════════
#   Fire  —  DFE été 2023, dept 6
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |     k3 |     k4 |   recall |   min_class |   AGG_DFE | Target   |
# |:---------------------------------------------------------------------|--------:|--------:|-------:|-------:|---------:|------------:|----------:|:---------|
# | Baseline DFE (2023)                                                  |  0.0160 |  0.0225 | 0.0441 | 0.0668 |   0.8563 |      1.0000 |  nan      | Fire     |
# | GRU_search_full_10_0_all_one_regression_pdegpd                       |  0.1015 |  0.0000 | 0.0000 | 0.0000 |   0.6149 |      1.0000 |   -0.1333 | Fire     |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.0494 |  0.0823 | 0.0000 | 0.0000 |   0.8333 |      1.0000 |   -0.0276 | Fire     |
# | GRU_search_full_10_0_all_one_classification_flwk                     | -0.1132 | -0.0998 | 0.0000 | 0.0000 |   0.6609 |      1.0000 |   -0.4870 | Fire     |
# | GRU_search_full_10_0_all_one_classification_bceloss                  | -0.0534 |  0.0000 | 0.0000 | 0.0000 |   0.4598 |      1.0000 |   -0.3754 | Fire     |
# | GRU_search_full_10_0_all_one_classification_fl                       | -0.0038 |  0.2152 | 0.0000 | 0.0000 |   0.8966 |      1.0000 |   -0.0313 | Fire     |
# | GRU_search_full_10_0_all_one_regression_cll                          | -0.0418 |  0.0217 | 0.0000 | 0.0000 |   0.5402 |      1.0000 |   -0.3133 | Fire     |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0018 |  0.0517 | 0.0650 | 0.0524 |   0.9368 |      1.0000 |    0.0501 | Fire     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Time  —  DFE été 2023, dept 6
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |      k3 |     k4 |   recall |   min_class |   AGG_DFE | Target   |
# |:---------------------------------------------------------------------|--------:|--------:|--------:|-------:|---------:|------------:|----------:|:---------|
# | Baseline DFE (2023)                                                  |  0.0658 |  0.0919 |  0.0957 | 0.0777 |   0.8555 |      1.0000 |  nan      | Time     |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    |  0.5510 |  0.0000 |  0.0149 | 0.1226 |   0.8324 |      1.0000 |    0.0001 | Time     |
# | GRU_search_full_10_0_all_one_classification_flwk                     | -0.1512 |  0.0000 |  0.0603 | 0.0381 |   0.7514 |      1.0000 |   -0.4227 | Time     |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     |  0.5118 |  0.0000 | -0.0356 | 0.0934 |   0.8902 |      1.0000 |   -0.0657 | Time     |
# | GRU_search_full_10_0_all_one_classification_wkloss                   | -0.9419 | -0.7513 | -0.4750 | 0.0892 |   0.9942 |      1.0000 |   -0.4541 | Time     |
# | GRU_search_full_10_0_all_one_classification_bceloss                  |  0.0825 |  0.0000 |  0.0522 | 0.0583 |   0.8439 |      1.0000 |   -0.1954 | Time     |
# | GRU_search_full_10_0_all_one_classification_fl                       |  0.2499 |  0.0000 |  0.0701 | 0.1063 |   0.7746 |      1.0000 |    0.0266 | Time     |
# | GRU_search_full_10_0_all_one_regression_cll                          | -1.1248 | -0.4547 | -0.4844 | 0.0000 |   0.8671 |      1.0000 |   -0.6062 | Time     |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.1382 |  0.2639 |  0.4230 | 0.0000 |   0.9075 |      1.0000 |    0.3274 | Time     |
#
#
# ═════════════════════════════════════════════════════════════════
#   Ressource  —  DFE été 2023, dept 6
# ═════════════════════════════════════════════════════════════════
# | Model                                                                |      k1 |      k2 |     k3 |      k4 |   recall |   min_class |   AGG_DFE | Target    |
# |:---------------------------------------------------------------------|--------:|--------:|-------:|--------:|---------:|------------:|----------:|:----------|
# | Baseline DFE (2023)                                                  |  0.1812 |  0.1784 | 0.2465 |  0.3716 |   0.8555 |      1.0000 |  nan      | Ressource |
# | GRU_search_full_10_0_all_one_classification_flwki-id{departement}    | -0.5747 | -0.2425 | 0.0436 | -0.0132 |   0.7919 |      1.0000 |   -0.5848 | Ressource |
# | GRU_search_full_10_0_all_one_classification_flwk                     | -0.0354 |  0.0666 | 0.0838 |  0.0376 |   0.7110 |      1.0000 |   -0.4749 | Ressource |
# | GRU_search_full_10_0_all_one_classification_weightedcrossentropy     | -0.9312 |  0.0000 | 0.0000 |  0.0000 |   0.4104 |      1.0000 |   -0.6271 | Ressource |
# | GRU_search_full_10_0_all_one_classification_wkloss                   | -0.0528 | -0.0259 | 0.2420 |  0.7750 |   0.8613 |      1.0000 |   -0.1486 | Ressource |
# | GRU_search_full_10_0_all_one_classification_bceloss                  |  0.5405 |  0.0000 | 0.8507 |  0.8033 |   0.9306 |      1.0000 |    0.3493 | Ressource |
# | GRU_search_full_10_0_all_one_classification_fl                       |  0.4888 |  0.0000 | 0.0000 |  0.0000 |   0.8266 |      1.0000 |   -0.2306 | Ressource |
# | GRU_search_full_10_0_all_one_regression_cll                          | -0.4122 |  0.1678 | 0.0000 |  0.0000 |   0.3179 |      1.0000 |   -0.5227 | Ressource |
# | GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} |  0.0424 |  0.2749 | 0.0000 |  0.0000 |   0.5376 |      1.0000 |   -0.3383 | Ressource |
#
# Index(['Model', 'Target', 'AGG', 'score_high', 'score_low', 'score_min_class',
#        'recall', 'score_k1', 'score_k2', 'score_k3', 'score_k4', 'coverage_k1',
#        'coverage_k2', 'coverage_k3', 'coverage_k4'],
#       dtype='object')
# Table de comparaison DFE sauvegardée dans : firemen2/comparison_dfe_scores.csv

# %%
# --- Visualization: Top-2 Models by AGG score per Target ---
import pandas as pd
import matplotlib.pyplot as plt

# We iterate over the simple names used in all_target_results
for simple_name in ['Fire', 'Time', 'Ressource']:
    if simple_name not in all_target_results:
        print(f"[{simple_name}] not found in all_target_results — skipping visualization.")
        continue
    
    res = all_target_results[simple_name]
    df_res = res.get('scores_lh_plot', pd.DataFrame())
    if df_res.empty: continue
    
    # Selection of top 2 models by AGG
    agg_candidates = [c for c in df_res.columns if 'AGG' in c]
    if not agg_candidates: continue
    
    agg_col = 'AGG_DFE_6' if 'AGG_DFE_6' in df_res.columns else agg_candidates[0]
    
    # Identify top 2 models
    #top_models = df_res.sort_values(agg_col, ascending=False).head(2)
    
    df_res = df_res.reset_index()
        
    top_models = df_res[(df_res['Model'].str.contains('ccllt')) | (df_res['Model'].str.contains('flwk-id')) | (df_res['Model'].str.contains('cll'))].set_index('Model')
        
    print(f"\n{'='*70}\n  VISUALIZING TOP-2 MODELS FOR: {simple_name} (sorted by {agg_col})\n{'='*70}")
    
    sc = scorers.get(simple_name)
    if sc is None:
        print(f"Scorer not found for {simple_name}"); continue
    
    # Find the short_key from SIMPLE_NAMES inverse
    short_key = None
    for k, v in SIMPLE_NAMES.items():
        if v == simple_name:
            short_key = k
            break
    
    # Use _INV_CLLT_TARGET_MAP to get target_key (long name)
    target_key = _INV_CLLT_TARGET_MAP.get(short_key)
    if target_key is None or target_key not in gt_dfs:
        print(f"Ground truth link not found for {simple_name} (short_key: {short_key})"); continue

    gt_df_orig = gt_dfs[target_key].copy()
    gt_df_orig['date'] = gt_df_orig['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
    gt_df_orig['date'] = pd.to_datetime(gt_df_orig['date'])
    gt_df_orig['num_zone'] = gt_df_orig['num_zone'].astype(int)
    
    for model_name, row in top_models.iterrows():
        print(f"\n>>> Plotting Fit for {model_name} (AGG: {row[agg_col]:.4f})")
        
        # Get predictions
        models_dict = all_data_frames.get(target_key, {})
        df_pred = models_dict.get(model_name)
        if df_pred is None:
            print(f"  Predictions not found for {model_name}"); continue
        
        df_p = df_pred.copy()
        df_p['date'] = df_p['date'].apply(lambda x: allDates[int(x)] if int(x)<len(allDates) else allDates[-1])
        df_p['date'] = pd.to_datetime(df_p['date'])
        df_p['num_zone'] = df_p['num_zone'].astype(int)

        # Merge for scoring. Use suffixes to avoid renaming the model's prediction columns.
        # We need the ground truth from gt_df_orig, so we take it from the '_gt' columns.
        merged = pd.merge(df_p, gt_df_orig, on=['date', 'num_zone'], how='inner', suffixes=('', '_gt'))
        merged = merged[merged['date'].dt.year == 2023]

        if not merged.empty:
            # Use target_key_gt as the ground truth classes for the scorer
            # Use risk_score as the model's predicted risk class
            sc._plot(merged['risk_score'], merged[f"{target_key}_gt"], merged['date'], merged['num_zone'], 
                    title=f"{simple_name} Monotonic Fit - {model_name}")
        else:
            print("  Empty merge for 2023 data — check date alignment.")
# Out:
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Fire (sorted by AGG_DFE_6)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_cll (AGG: -0.3133)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: 0.0501)
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Time (sorted by AGG_DFE_6)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_cll (AGG: -0.6062)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: 0.3274)
# ======================================================================
#   VISUALIZING TOP-2 MODELS FOR: Ressource (sorted by AGG_DFE_6)
# ======================================================================
#
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_cll (AGG: -0.5227)
# >>> Plotting Fit for GRU_search_full_10_0_all_one_regression_ccllt-id{node}-nclusters{30} (AGG: -0.3383)
