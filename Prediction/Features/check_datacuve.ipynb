# %%
from tools import *

path = Path('/media/caron/X9 Pro1/travaille/Thèse/csv/departement-01-ain/raster/2x2')

datacube = read_object('datacube.pkl', path)

# %%
datacube
# Out:
# <xarray.Dataset>
# Dimensions:                   (latitude: 45, longitude: 51, date: 2574)
# Coordinates:
#   * latitude                  (latitude) int64 0 1 2 3 4 5 ... 39 40 41 42 43 44
#   * longitude                 (longitude) int64 0 1 2 3 4 5 ... 46 47 48 49 50
#   * date                      (date) <U10 '2017-06-12' ... '2024-06-28'
# Data variables: (12/32)
#     temp                      (latitude, longitude, date) float64 nan ... nan
#     dwpt                      (latitude, longitude, date) float64 nan ... nan
#     rhum                      (latitude, longitude, date) float64 nan ... nan
#     prcp                      (latitude, longitude, date) float64 nan ... nan
#     wdir                      (latitude, longitude, date) float64 nan ... nan
#     wspd                      (latitude, longitude, date) float64 nan ... nan
#     ...                        ...
#     prec24h16                 (latitude, longitude, date) float64 nan ... nan
# ...

# %%
import matplotlib.pyplot as plt

# On suppose que datacube est un xarray Dataset ou DataArray
# Et qu'on a une feature nommée 'temperature'

datacube['temp'].mean(dim=['date']).plot()
plt.title("Average Temperature Over Time")
plt.xlabel("Time")
plt.ylabel("Temperature (°C)")
plt.show()
