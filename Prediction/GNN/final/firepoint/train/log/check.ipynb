# %%
import geopandas as gpd
import pickle
import matplotlib.pyplot as plt

r = gpd.read_file('departement-01-ain_bin0.geojson')
r.plot()
# Out:
# <Axes: >

# %%
array = pickle.load(open('departement-01-ainpastInfluence.pkl', 'rb'))
plt.imshow(array[:,:,3])
