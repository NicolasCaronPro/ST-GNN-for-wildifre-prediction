# %%
import pandas as pd

data = pd.read_csv('firepoint.csv')

data = data[(data['year'] > 2017)]

#data.dropna(subset='date_debut', inplace=True)
data = data[data['departement'].isin(['departement-01-ain', 'departement-25-doubs', 'departement-78-yvelines'])]
#data.departement.unique()

# %%
data['Hour'] = data['date_debut'].apply(lambda x : int(x.split(' ')[1].split(':')[0]))
data['Hour'].hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 data['Hour'] = data['date_debut'].apply(lambda x : int(x.split(' ')[1].split(':')[0]))
#       2 data['Hour'].hist()
#
# File ~/Bureau/.conda/lib/python3.9/site-packages/pandas/core/series.py:4897, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)
#    4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)
#    4895     dtype: float64
#    4896     """
# -> 4897     return SeriesApply(
#    4898         self,
#    4899         func,
#    4900         convert_dtype=convert_dtype,
#    4901         by_row=by_row,
#    4902         args=args,
#    4903         kwargs=kwargs,
#    4904     ).apply()
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Générer un histogramme où toutes les heures de 0 à 23 sont représentées
hour_bins = list(range(0, 25))  # Les bords des bins vont de 0 à 24 pour inclure 23
hour_counts = data['Hour'].value_counts().reindex(range(24), fill_value=0)

# Tracé avec une taille de figure agrandie
plt.figure(figsize=(12, 6))  # Augmente la taille de la figure (largeur=12, hauteur=6)
plt.bar(hour_counts.index, hour_counts.values, color='blue', alpha=0.7)
plt.xticks(range(24))  # Affiche toutes les heures de 0 à 23
plt.xlabel('Hour')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
data[data['year'] == 2023].departement.unique()
# Out:
# array(['departement-01-ain', 'departement-25-doubs',
#        'departement-78-yvelines'], dtype=object)

# %%
import pandas as pd
import matplotlib.pyplot as plt

hour_bins = list(range(2018, 2023))  # Les bords des bins vont de 0 à 24 pour inclure 23
hour_counts = data['year'].value_counts()

# Tracé avec une taille de figure agrandie
plt.figure(figsize=(12, 6))  # Augmente la taille de la figure (largeur=12, hauteur=6)
plt.bar(hour_counts.index, hour_counts.values, color='blue', alpha=0.7)
plt.xlabel('Years')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
hour_counts
# Out:
# year
# 2020.0    1718
# 2018.0    1463
# 2019.0    1406
# 2022.0     945
# 2023.0     533
# 2021.0     503
# Name: count, dtype: int64
