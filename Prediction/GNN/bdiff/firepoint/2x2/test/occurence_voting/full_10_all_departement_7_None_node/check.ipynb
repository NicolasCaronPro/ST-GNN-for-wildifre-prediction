# %%
import pandas as pd

file = pd.read_csv('df_metrics_node.csv')

# %%
file.Run.loc[0]
# Out:
# 'all_STGATLSTM_search_full_all_one_nbsinister-kmeans-5-Class-Dept_classification_weightedcrossentropy_full_10_all_departement_7_None_node'
