# %%
import sys

sys.path.insert(0, '/home/caron/Bureau/Model/HexagonalScale/ST-GNN-for-wildifre-prediction/Prediction')

from GNN.tools import *

# %%
datacube = read_object('datacube_target_2_risk-size-watershed-degree-a4-r6-t0.3_node.pkl', Path('bdiff/firepoint/2x2/train/datacube'))

# %%
datacube
# Out:
# <xarray.Dataset>
# Dimensions:                  (departement: 1, latitude: 40, longitude: 36,
#                               date: 2574)
# Coordinates:
#   * departement              (departement) object 'departement-06-alpes-marit...
#   * latitude                 (latitude) float64 44.34 44.32 44.3 ... 43.55 43.53
#   * longitude                (longitude) float64 6.679 6.708 ... 7.657 7.685
#   * date                     (date) <U10 '2017-06-12' ... '2024-06-28'
# Data variables:
#     occurence                (departement, latitude, longitude, date) float64 ...
#     burned_area              (departement, latitude, longitude, date) float64 ...
#     time_intervention        (departement, latitude, longitude, date) float64 ...
#     influence                (departement, latitude, longitude, date) float64 ...
#     occurence_scale          (departement, latitude, longitude, date) float64 ...
#     influence_scale          (departement, latitude, longitude, date) float64 ...
# ...

# %%
import matplotlib.pyplot as plt

datacube['area'].plot()
plt.title("Average Temperature Over Time")
plt.xlabel("Time")
plt.ylabel("Temperature (°C)")
plt.show()
