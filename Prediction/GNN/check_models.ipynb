# %%
from tools import *
from xgboost import plot_tree

path = Path('/home/caron/Bureau/Model/HexagonalScale/ST-GNN-for-wildifre-prediction/Prediction/GNN/Yvelines/firepoint/2x2/train/check_z-score/full_0_10_100/baseline/')

features_map = open(path / 'xgboost_risk' / 'feature_map.text')

model = read_object('xgboost_risk.pkl', path / 'xgboost_risk')
plt.plot(model.best_estimator_.feature_importances_)
print(model.best_estimator_.feature_importances_.shape)
# Out:
# (100,)

# %%
model.best_estimator_.get_params()
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': 0.8,
#  'colsample_bynode': None,
#  'colsample_bytree': 0.8,
#  'device': None,
#  'early_stopping_rounds': 15,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': 0.01,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': 1.0,
#  'max_depth': 15,
#  'max_leaves': None,
#  'min_child_weight': 5.0,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': 10000,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': 42,
#  'reg_alpha': 0.9,
#  'reg_lambda': 10.5,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': 0.3,
#  'tree_method': 'hist',
#  'validate_parameters': None,
# ...

# %%
features_list = features_map.read().split('\n')

# %%
features_list
# Out:
# ['Historical_sum q',
#  'Historical_max q',
#  'dmc_min q',
#  'bui_min q',
#  'dmc_sum q',
#  'dmc_max q',
#  'Historical_mean q',
#  'bui_max q',
#  'Historical_std q',
#  'dayofyear q',
#  'nesterov_max q',
#  'nesterov_mean q',
#  'nesterov_sum q',
#  'angstroem_min q',
#  'fwi_sum q',
#  'fwi_max q',
#  'kbdi_min q',
#  'kbdi_max q',
#  'bui_sum q',
#  'temp_sum q',
#  'dailySeverityRating_max q',
#  'dailySeverityRating_sum q',
#  'kbdi_sum q',
#  'bare_max q',
#  'dmc_mean q',
#  'munger_std q',
#  'mean q',
#  'kbdi_mean q',
#  'bui_mean q',
#  'nesterov_std q',
#  'B-1 q',
#  'built_std q',
#  'bare_mean q',
#  'temp16_sum q',
#  'dailySeverityRating_min q',
#  'kbdi_std q',
#  'built_max q',
#  'fwi_mean q',
#  'dc_std q',
#  'built_sum q',
#  'ffmc_max q',
#  'ffmc_sum q',
#  'angstroem_mean q',
#  'munger_max q',
#  'angstroem_max q',
#  'month q',
#  'tree_max q',
#  'fwi_min q',
#  'dailySeverityRating_mean q',
#  'fwi_std q',
#  'built_mean q',
#  'bui_std q',
# ...

# %%
model.best_estimator_.feature_importances_.shape
# Out:
# (100,)

# %%
model.best_estimator_.best_iteration
# Out:
# 1611

# %%
model.best_estimator_.get_booster().feature_names = features_list[:-1]

# %%
model.best_estimator_.best_iteration
# Out:
# 1611

# %%
fig, ax = plt.subplots(1, figsize=(300,400))
plot_tree(model.best_estimator_, num_trees=1611, ax=ax)
plt.savefig(path / 'xgboost_risk' / 'best_iteration.png')
plt.show()
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.571302 to fit
