# %%
from graph_structure import GraphStructure
import geopandas as gpd

scale = 5
maxDist = 20
numNei = 6
geo = gpd.read_file('regions/regions.geojson')

graph = GraphStructure(scale, geo, maxDist, numNei)
graph._train_kmeans(doRaster=False, path=None)
graph._create_nodes_list()
graph._create_edges_list()
graph._plot(graph.nodes)
# Out:
# Create node via KMEANS
# Creating node list
# Creating edges list
